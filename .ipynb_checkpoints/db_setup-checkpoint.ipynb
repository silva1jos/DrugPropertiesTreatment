# %% [markdown]
# ### Joshua Silva

# %%
from chembl_webresource_client.new_client import new_client
import csv
import sqlite3

# %% [markdown]
# ## Getting data through api, determining potential features, and saving initial data to SQLite DB

# %%
# Making a call to the api for a structure by smiles string,'C[N+](C)(C)CCOC(N)=O'
# originally was going to use smiles from the ZINC DB but a simpler solution was found
r = new_client.molecule.filter(molecule_structures__canonical_smiles__flexmatch='C[N+](C)(C)CCOC(N)=O')

# %%
r[0]
# important fields
# molecule_chembl_id
# molecule_properties
# indication_class -> more indications exist than are listed from this call, from looking at website
# chirality
# Others will not be predictive for the models being used
# Out:
# {'atc_classifications': [],
#  'availability_type': '1',
#  'biotherapeutic': None,
#  'black_box_warning': '0',
#  'chebi_par_id': None,
#  'chirality': '2',
#  'cross_references': [{'xref_id': 'carbachol',
#    'xref_name': 'carbachol',
#    'xref_src': 'DailyMed'},
#   {'xref_id': '11110943', 'xref_name': 'SID: 11110943', 'xref_src': 'PubChem'},
#   {'xref_id': '11110944', 'xref_name': 'SID: 11110944', 'xref_src': 'PubChem'},
#   {'xref_id': '26756576', 'xref_name': 'SID: 26756576', 'xref_src': 'PubChem'},
#   {'xref_id': '90341139',
#    'xref_name': 'SID: 90341139',
#    'xref_src': 'PubChem'}],
#  'dosed_ingredient': False,
#  'first_approval': 1972,
#  'first_in_class': '0',
#  'helm_notation': None,
#  'indication_class': 'Cholinergic (ophthalmic)',
#  'inorganic_flag': '0',
#  'max_phase': 4,
#  'molecule_chembl_id': 'CHEMBL965',
#  'molecule_hierarchy': {'molecule_chembl_id': 'CHEMBL965',
#   'parent_chembl_id': 'CHEMBL965'},
#  'molecule_properties': {'acd_logd': '-4.1',
#   'acd_logp': '-4.1',
#   'acd_most_apka': '12.54',
#   'acd_most_bpka': None,
#   'alogp': '-0.21',
#   'aromatic_rings': 0,
#   'full_molformula': 'C6H15N2O2+',
#   'full_mwt': '147.2',
#   'hba': 2,
#   'hba_lipinski': 4,
#   'hbd': 1,
#   'hbd_lipinski': 2,
#   'heavy_atoms': 10,
#   'molecular_species': 'NEUTRAL',
#   'mw_freebase': '147.2',
#   'mw_monoisotopic': '147.1128',
#   'num_lipinski_ro5_violations': 0,
#   'num_ro5_violations': 0,
#   'psa': '52.32',
#   'qed_weighted': '0.56',
#   'ro3_pass': 'Y',
#   'rtb': 3},
#  'molecule_structures': {'canonical_smiles': 'C[N+](C)(C)CCOC(=O)N',
#   'standard_inchi': 'InChI=1S/C6H14N2O2/c1-8(2,3)4-5-10-6(7)9/h4-5H2,1-3H3,(H-,7,9)/p+1',
#   'standard_inchi_key': 'VPJXQGSRWJZDOB-UHFFFAOYSA-O'},
#  'molecule_synonyms': [{'molecule_synonym': 'Carbachol',
#    'syn_type': 'BAN',
#    'synonyms': 'CARBACHOL'},
#   {'molecule_synonym': 'Carbachol',
#    'syn_type': 'JAN',
#    'synonyms': 'CARBACHOL'},
#   {'molecule_synonym': 'Carbachol',
#    'syn_type': 'USP',
#    'synonyms': 'CARBACHOL'},
#   {'molecule_synonym': 'Carbachol',
#    'syn_type': 'USAN',
#    'synonyms': 'Carbachol'},
#   {'molecule_synonym': 'Carbastat',
#    'syn_type': 'OTHER',
#    'synonyms': 'Carbastat'},
#   {'molecule_synonym': 'Miostat', 'syn_type': 'OTHER', 'synonyms': 'Miostat'}],
#  'molecule_type': 'Small molecule',
#  'natural_product': '0',
#  'oral': False,
#  'parenteral': True,
#  'polymer_flag': False,
#  'pref_name': 'CARBACHOL',
#  'prodrug': '0',
#  'structure_type': 'MOL',
#  'therapeutic_flag': True,
#  'topical': False,
#  'usan_stem': None,
#  'usan_stem_definition': None,
#  'usan_substem': None,
#  'usan_year': None,
#  'withdrawn_class': None,
#  'withdrawn_country': None,
#  'withdrawn_flag': False,
#  'withdrawn_reason': None,
#  'withdrawn_year': None}

# %%
# Able to pull drug id's by indication, this may be the only way to link together all indications
# Indication class from the molecule search is not the same as the indication here
drug_indication = new_client.drug_indication
lung_cancer_ind = drug_indication.filter(efo_term__icontains="LUNG CARCINOMA").only(
    ['molecule_chembl_id'])

# %%
# Pulling the important fields for the drug id's from the indication, which are approved
molecules = new_client.molecule
lung_cancer_mols = molecules.filter(
    molecule_chembl_id__in=[x['molecule_chembl_id'] for x in lung_cancer_ind], max_phase=4).only(
    ['molecule_chembl_id', 'molecule_properties', 'indication_class', 'chirality', 'molecule_structures'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-32167ae4ce6c> in <module>()
#       2 molecules = new_client.molecule
#       3 lung_cancer_mols = molecules.filter(
# ----> 4     molecule_chembl_id__in=[x['molecule_chembl_id'] for x in lung_cancer_ind], max_phase=4).only(
#       5     ['molecule_chembl_id', 'molecule_properties', 'indication_class', 'chirality', 'molecule_structures'])
#
# NameError: name 'lung_cancer_ind' is not defined

# %%
# Pulling only approved drugs, max phase = 4 this may be sufficient, getting the data cared about
# A significant portion of the data had no smiles string so this was not ultimately used
approved_mols = molecules.filter(max_phase=4).only(
    ['molecule_chembl_id', 'molecule_properties','indication_class', 'chirality', 'molecule_structures'])

# %%
# Pulling out the indications which we want to predict
indications = [x['indication_class'] for x in approved_mols]

# %%
# Saving the approved drugs in case of api issues
with open('approved.txt', 'w') as f:
    for item in approved_mols:
        f.write("%s\n" % item)

# %%
# All 585 Indications
with open('indications.csv', 'w') as f:
    for item in set(indications):
        f.write("%s\n" % item)
# Out:
# {'Acidifier',
#  'Acidifier (urlnary); Vitamin (antiscorbutic)',
#  'Acidifier; Diuretic',
#  'Adrenergic',
#  'Adrenergic (alpha12-agonist)',
#  'Adrenergic (ophthalmic)',
#  'Adrenergic (ophthalmic),Adrenergic (vasoconstrictor)',
#  'Adrenergic (ophthalmic),Antiglaucoma Agent',
#  'Adrenergic (vasoconstrictor)',
#  'Adrenergic (vasoconstrictor),Decongestant,Nasal Decongestant',
#  'Adrenergic,Bronchodilator',
#  'Adrenocortical Steroid (salt-regulating)',
#  'Adrenocortical Steroid,Glucocorticoid',
#  'Adrenocortical Suppressant',
#  'Adrenocortical Suppressant; Antineoplastic',
#  'Advanced Colorectal Cancer Treatment (thymidylate synthase inhibitor)',
#  'Alcohol Deterrent',
#  'Aldosterone Antagonist',
#  'Alkalizer',
#  'Alkalizer (systemic)',
#  'Alkalizer (systemic); Replenisher (electrolyte)',
#  "Alzheimer's Disease Treatment (adjunct)",
#  'Amino Acid',
#  'Amino Acid,Radioactive Agent',
#  'Ammonia Detoxicant',
#  'Amyotrophic Lateral Sclerosis Treatment',
#  'Anabolic',
#  'Analeptic (treatment of narcolepsy hypersomnia)',
#  'Analgesic',
#  'Analgesic (narcotic)',
#  'Analgesic (narcotic); Antitussive',
#  'Analgesic (narcotic); Antitussive,Antitussive,Antitussive; Analgesic (narcotic)',
#  'Analgesic (specific in migraine)',
#  'Analgesic (urinary tract)',
#  'Analgesic,Analgesic (narcotic)',
#  'Analgesic,Ultraviolet Screen',
#  'Analgesic; Anti-Inflammatory',
#  'Analgesic; Anti-Inflammatory,Anti-Inflammatory; Analgesic',
#  'Analgesic; Anticonvulsant',
#  'Analgesic; Antipyretic',
#  'Analgesic; Antirheumatic; Antipyretic',
#  'Analgesic; Antitussive',
#  'Androgen',
#  'Anesthesia, Adjunct To',
#  'Anesthetic',
#  'Anesthetic (inhalation)',
#  'Anesthetic (injectable)',
#  'Anesthetic (injectable),Anesthetic (intravenous)',
#  'Anesthetic (intravenous)',
#  'Anesthetic (intravenous); Anticonvulsant',
#  'Anesthetic (local)',
#  'Anesthetic (local),Anesthetic (topical)',
#  'Anesthetic (topical)',
#  'Anesthetic (topical, ophthalmic)',
#  'Anhidrotic',
#  'Anorexic',
#  'Anorexic,Appetite Suppressant (systemic)',
#  'Antacid',
#  'Antagonist (angiotensin II receptor); Antihypertensive',
#  'Antagonist (bradykinin)',
#  'Antagonist (calcium channel)',
#  'Antagonist (endothelin receptor)',
#  'Antagonist (oxytocin)',
#  'Antagonist (to benzodiazepine)',
#  'Antagonist (to histamine-H2 receptors)',
#  'Antagonist (to narcotics)',
#  'Antagonist (to narcotics); Analgesic',
#  'Anterior Pituitary Suppressant',
#  'Anthelmintic',
#  'Anthelmintic (veterinary)',
#  'Anti-Acne',
#  'Anti-Adrenergic',
#  'Anti-Adrenergic (beta-receptor)',
#  'Anti-Adrenergic (beta-receptor),Antihypertensive,Antihypertensive; Anti-Anginal',
#  'Anti-Adrenergic (beta-receptor); Anti-Adrenergic (alpha-receptor)',
#  'Anti-Adrenergic (beta-receptor); Antihypertensive',
#  'Anti-Allergic',
#  'Anti-Allergic (prophylactic)',
#  'Anti-Allergic; Anti-Asthmatic',
#  'Anti-Allergic; Antihistaminic, H1-Receptor; Asthma Prophylactic',
#  'Anti-Allergic; Inhibitor (mediator release)',
#  'Anti-Amebic',
#  'Anti-Amebic; Anti-Infective, Topical',
#  'Anti-Amebic; Antimalarial',
#  'Anti-Amebic; Antimalarial,Anti-Amebic; Suppressant (lupus erythematosus); Antimalarial',
#  'Anti-Amebic; Antirickettsial; Antibacterial',
#  'Anti-Amebic; Antirickettsial; Antibacterial,Antibacterial,Antibacterial; Anti-Amebic; Antirickettsial',
#  'Anti-Amebic; Suppressant (lupus erythematosus); Antimalarial',
#  'Anti-Androgen',
#  'Anti-Anemic; Hematinic',
#  'Anti-Anginal',
#  'Anti-Anginal; Cardiac Depressant (anti-arrhythmic)',
#  'Anti-Anginal; Cardiac Depressant (anti-arrhythmic),Vasodilator (coronary)',
#  'Anti-Anxiety Agent',
#  'Anti-Anxiety Agent; Anti-Emetic; Antischizophrenic',
#  'Anti-Asthmatic',
#  'Anti-Asthmatic (leukotriene antagonist)',
#  'Anti-Asthmatic (prophylactic)',
#  'Anti-Asthmatic; Anti-Allergic',
#  'Anti-Eczematic (topical)',
#  'Anti-Emetic',
#  'Anti-Emetic,Anti-Emetic; Antipsychotic,Antipsychotic; Anti-Emetic',
#  'Anti-Emetic,Antihistaminic,Antinauseant',
#  'Anti-Epileptic',
#  'Anti-Estrogen',
#  'Anti-Estrogen; Antineoplastic',
#  'Anti-Infective',
#  'Anti-Infective, Topical',
#  'Anti-Infective, Topical,Antibacterial',
#  'Anti-Infective, Topical,Antibacterial,Antimicrobial',
#  'Anti-Infective, Topical; Antiprotozoal (trichomonas, topical)',
#  'Anti-Infective, Topical; Detergent',
#  'Anti-Infective, Topical; Pharmaceutic Aid (preservative)',
#  'Anti-Infective, Topical; Pharmaceutic Aid (solvent)',
#  'Anti-Inflammatory',
#  'Anti-Inflammatory (gastrointestinal)',
#  'Anti-Inflammatory (interstitial cystitis)',
#  'Anti-Inflammatory (nonsteroidal)',
#  'Anti-Inflammatory (topical)',
#  'Anti-Inflammatory,Anti-Inflammatory; Analgesic',
#  'Anti-Inflammatory; Analgesic',
#  'Anti-Inflammatory; Analgesic,Inhibitor (prostaglandin synthesis)',
#  'Anti-Inflammatory; Antipyretic; Analgesic',
#  'Anti-Inflammatory; Antipyretic; Analgesic,Antipyretic; Anti-Inflammatory; Analgesic',
#  'Anti-Ulcerative',
#  'Anti-Ulcerative (gastrointestinal)',
#  'Anti-Ulcerative; Gastric Acid Pump Inhibitor',
#  'Anti-Urolithic',
#  'Anti-Urolithic (cystine calculi)',
#  'Antibacterial',
#  'Antibacterial (antimycobacterial)',
#  'Antibacterial (leprostatic); Suppressant (dermatitis herpetiformis)',
#  'Antibacterial (microbial DNA topoisomerase inhibitor)',
#  'Antibacterial (ophthalmic)',
#  'Antibacterial (systemic)',
#  'Antibacterial (topical)',
#  'Antibacterial (tuberculostatic)',
#  'Antibacterial (tuberculostatic); Antibacterial (leprostatic)',
#  'Antibacterial (urinary)',
#  'Antibacterial,Antibacterial; Antiprotozoal',
#  'Antibacterial,Antiprotozoal (trichomonas)',
#  'Antibacterial,Antirickettsial; Antibacterial',
#  'Antibacterial; Antiprotozoal',
#  'Antibacterial; Antiprotozoal,Antiprotozoal; Antibacterial',
#  'Antibacterial; Antirickettsial',
#  'Anticholelithic (dissolution of gallstones)',
#  'Anticholelithogenic',
#  'Anticholinergic',
#  'Anticholinergic (ophthalmic)',
#  'Anticholinergic,Anticholinergic (ophthalmic)',
#  'Anticholinergic; Antiparkinsonian',
#  'Anticholinergic; Antiparkinsonian,Antiparkinsonian; Anticholinergic',
#  'Anticoagulant',
#  'Anticoagulant; Antithrombotic',
#  'Anticonvulsant',
#  'Anticonvulsant (tardive dyskinesia)',
#  'Anticonvulsant; Replenisher (electrolyte); Laxative',
#  'Anticonvulsant; Sedative-Hypnotic',
#  'Anticonvulsant; Sedative-Hypnotic,Sedative-Hypnotic; Anticonvulsant',
#  'Antidepressant',
#  'Antidepressant,Psychotropic',
#  'Antidepressant; Anorexic',
#  'Antidepressant; Antischizophrenic; Dopamine Agonist; Antiparkinsonian,Antiparkinsonian; Antischizophrenic; Dopamine Agonist; Antidepressant',
#  'Antidiabetic',
#  'Antidiabetic,Diagnostic Aid (diabetes)',
#  'Antidiarrheal; Anti-Ulcerative; Antacid',
#  'Antidiuretic',
#  'Antidiuretic; Vasoconstrictor',
#  'Antidote (alcohol dehydrogenase inhibitor)',
#  'Antidote (to arsenic and gold and mercury poisoning)',
#  'Antidote (to curare principles); Diagnostic Aid (myasthenia gravis)',
#  'Antidote (to cyanide poisoning)',
#  'Antidote (to cyanide poisoning); Antimethemoglobinemic',
#  'Antidote (to folic acid antagonists)',
#  'Antidote (to folic acid antagonists); Anti-Anemic (folate deficiency)',
#  'Antidote (to heparin)',
#  'Antidote (to iron poisoning); Chelating Agent',
#  'Antidote (to iron poisoning); Chelating Agent,Chelating Agent (iron)',
#  'Antidote (to phosphorus)',
#  'Antidyskinetic',
#  "Antidyskinetic (in gilles de la tourette's disease); Antipsychotic",
#  'Antidyskinetic; Antiparkinsonian (in combination with levodopa/carbidopa)',
#  'Antifiatulent',
#  'Antifungal',
#  'Antifungal; Antibacterial',
#  'Antifungal; Antiseborrheic',
#  'Antiglaucoma Agent',
#  'Antiglaucoma Agent; Cholinergic (ophthalmic),Cholinergic (ophthalmic)',
#  'Antiglaucoma Agent; Psychotropic; Adrenergic (alpha-blocking); Neuroleptic',
#  'Antihistaminic',
#  'Antihistaminic; Anti-Allergic',
#  'Antihistaminic; Anti-Emetic',
#  'Antihistaminic; Antipruritic',
#  'Antihistaminic; Relaxant (skeletal muscle)',
#  'Antihistaminic; Serotonin Inhibitor',
#  'Antihyperammonemic',
#  'Antihyperammonemic; Pharmaceutic Aid (antifungal agent)',
#  'Antihypercalcemic; Bone Resorption Inhibitor',
#  'Antihyperlipidemic',
#  'Antihyperlipidemic; Inhibitor (HMG-CoA reductase)',
#  'Antihyperlipidemic; Ion-Exchange Resin (bile salts)',
#  'Antihyperlipoproteinemic',
#  'Antihyperphosphatemic',
#  'Antihypertensive',
#  'Antihypertensive (alpha-blocker)',
#  'Antihypertensive (angiotensin II receptor antagonist)',
#  'Antihypertensive (beta-blocker)',
#  'Antihypertensive (beta-blocker, ophthalmic)',
#  'Antihypertensive (vasodilator)',
#  'Antihypertensive,Enzyme Inhibitor (angiotensin-converting)',
#  'Antihypertensive,Vasodilator (coronary)',
#  'Antihypertensive; Aldosterone Antagonist',
#  'Antihypertensive; Anti-Anginal',
#  'Antihypertensive; Diuretic',
#  'Antihypertensive; Diuretic,Diuretic',
#  'Antihypertensive; Enzyme Inhibitor (angiotensin-converting)',
#  'Antihypotensive',
#  'Antimalarial',
#  'Antimalarial,Antiprotozoal',
#  'Antimalarial,Deterrent (smoking)',
#  'Antimalarial; Suppressant (lupus erythematosus)',
#  'Antimanic',
#  'Antimicrobial',
#  'Antimigraine',
#  'Antimigraine; Anti-Emetic',
#  'Antimitotic',
#  'Antimycotic',
#  'Antinauseant',
#  'Antinauseant; Anti-Emetic',
#  'Antineoplastic',
#  'Antineoplastic (DNA topoisomerase I Inhibitor)',
#  'Antineoplastic,Antisecretory (gastric)',
#  'Antineoplastic; Antiprotozoal',
#  'Antineoplastic; Biological Response Modifier',
#  'Antineoplastic; Radioactive Agent',
#  'Antineoplastic; Radioactive Agent,Radioactive Agent',
#  'Antineuralgic, Specific Pain Syndromes, Topical; Analgesic (topical)',
#  'Antineutropenic; Hematopoietic Stimulant',
#  'Antiobsessional Agent',
#  'Antiparasitic',
#  'Antiparkinsonian',
#  'Antiparkinsonian (D2 receptor agonist)',
#  'Antiparkinsonian; Anticholinergic',
#  'Antiparkinsonian; Relaxant (skeletal muscle)',
#  'Antiperistaltic',
#  'Antipneumocystic',
#  'Antiprotozoal',
#  'Antiprotozoal; Antibacterial',
#  'Antipruritic',
#  'Antipruritic (topical)',
#  'Antipsoriatic',
#  'Antipsychotic',
#  'Antipsychotic; Anti-Emetic',
#  'Antipsychotic; Antischizophrenic',
#  'Antipsychotic; Neuroleptic',
#  'Antipsychotic; Sedative-Hypnotic',
#  'Antipsychotic; Sedative-Hypnotic,Sedative-Hypnotic; Antipsychotic',
#  'Antipyretic; Analgesic; Anti-Inflammatory',
#  'Antipyretic; Anti-Inflammatory; Analgesic',
#  'Antirheumatic',
#  'Antirheumatic; Anti-Inflammatory',
#  'Antirickettsial; Antibacterial',
#  'Antischistosomal',
#  'Antiseborrheic',
#  'Antisecretory (gastric)',
#  'Antisecretory (gastric),Depressant (gastric acid secretory)',
#  'Antisense Antiviral Used In The Therapy of Cytomegalovirus Retinitis',
#  'Antiseptic; Anti-Ulcerative',
#  'Antispasmodic',
#  'Antithrombotic',
#  'Antithrombotic; Anticoagulant',
#  'Antitussive',
#  'Antitussive; Analgesic (narcotic)',
#  'Antiviral',
#  'Antiviral (ophthalmic)',
#  'Antiviral,Antiviral; Antineoplastic',
#  'Antiviral; Antineoplastic',
#  'Appetite Suppressant (systemic)',
#  'Astringent',
#  'Astringent (ophthalmic)',
#  'Astringent; Dentin Desensitizer',
#  'Barrier for The Prevention of Allergic Contact Dermatitis',
#  'Benign Prostatic Hyperplasia Therapy Agent',
#  'Biological Response Modifier',
#  'Biological Response Modifier; Antineoplastic',
#  'Biological Response Modifier; Antineoplastic; Immunostimulant',
#  'Biological Response Modifier; Antiviral',
#  'Blood Substitute',
#  'Blood Volume Supporter',
#  'Bone Resorption Inhibitor',
#  'Bone Resorption Inhibitor,Regulator (calcium)',
#  'Bone Resorption Inhibitor; Osteoporosis Therapy Adjunct',
#  'Bone Resorption Inhibitor; Osteoporosis Therapy Adjunct,Osteoporosis Therapy Adjunct,Osteoporosis Therapy Adjunct; Bone Resorption Inhibitor',
#  'Bronchodilator',
#  'Bronchodilator,Diuretic; Relaxant (smooth muscle),Relaxant (smooth muscle)',
#  'Bronchodilator; Asthma Prophylactic',
#  'Carbonic Anhydrase Inhibitor',
#  'Cardiac Depressant (anti-arrhythmic)',
#  'Cardiac Depressant (anti-arrhythmic); Anti-Adrenergic',
#  'Cardiac Depressant (anti-arrhythmic); Anti-Adrenergic (beta-receptor)',
#  'Cardioprotectant',
#  'Cardiotonic',
#  'Cardiovascular Agent',
#  'Carminative; Stomachic; Counterirritant (external)',
#  'Chelating Agent',
#  'Chelating Agent (metal)',
#  'Chelating Agent (plutonium)',
#  'Chelating Agent (plutonium),Diagnostic Aid',
#  'Choleretic',
#  'Cholinergic',
#  'Cholinergic (ophthalmic)',
#  'Cholinesterase Reactivator',
#  'Chronic Dermal Ulcers Treatment (promotes the proliferation of mesenchymally-derived cells)',
#  'Cognition Adjuvant',
#  'Cognition Adjuvant; Dementia Symptoms Treatment Adjunct',
#  'Cystic Fibrosis Therapy Adjunct',
#  "Dementia Symptoms Treatment Adjunct; Inhibitor (acetylcholinesterase); Cognition Adjuvant; Alzheimer's Disease Treatment (adjunct)",
#  'Dental Caries Prophylactic',
#  'Dental Caries Prophylactic,Radioactive Agent',
#  'Depigmentor',
#  'Detergent',
#  'Detoxifying Agent',
#  'Diagnostic Aid',
#  'Diagnostic Aid (adrenocortical insufficiency); Glucocorticoid; Hormone (adrenocorticotropic),Diagnostic Aid (adrenocortical insufficiency); Hormone (adrenocorticotropic); Glucocorticoid',
#  'Diagnostic Aid (blood volume determination); Radioactive Agent',
#  'Diagnostic Aid (brain imaging); Radioactive Agent',
#  'Diagnostic Aid (corneal trauma indicator)',
#  'Diagnostic Aid (diabetes)',
#  'Diagnostic Aid (gastric secretion indicator)',
#  'Diagnostic Aid (hepatic function determination); Diagnostic Aid (cardiac output determination)',
#  'Diagnostic Aid (hepatobiliary function determination); Radioactive Agent',
#  'Diagnostic Aid (hypocalcemia)',
#  'Diagnostic Aid (intestinal function determination)',
#  'Diagnostic Aid (intrathecal imaging); Radioactive Agent; Diagnostic Aid (blood volume determination)',
#  'Diagnostic Aid (lung imaging)',
#  'Diagnostic Aid (lymphangiography)',
#  'Diagnostic Aid (neoplasm); Antineoplastic; Radioactive Agent; Antipolycythemic',
#  'Diagnostic Aid (neoplasm); Antineoplastic; Radioactive Agent; Antipolycythemic,Laxative',
#  'Diagnostic Aid (pancreas function determination)',
#  'Diagnostic Aid (pancreas function determination); Radioactive Agent',
#  'Diagnostic Aid (paramagnetic)',
#  'Diagnostic Aid (paramagnetic, brain disorders, spine disorders)',
#  'Diagnostic Aid (penicillin sensitivity)',
#  'Diagnostic Aid (pernicious anemia); Radioactive Agent',
#  'Diagnostic Aid (pernicious anemia); Radioactive Agent,Radioactive Agent; Diagnostic Aid (pernicious anemia),Vitamin (hematopoietic)',
#  'Diagnostic Aid (pituitary function determination)',
#  'Diagnostic Aid (radioactive, adrenomedullary disorders and neuroendocrine tumors); Radioactive Agent,Radioactive Agent,Radioactive Agent; Diagnostic Aid',
#  'Diagnostic Aid (radioactive, cardiac disease); Radioactive Agent',
#  'Diagnostic Aid (radioactive, vascular disorders); Radioactive Agent,Radioactive Agent',
#  'Diagnostic Aid (radiopaque medium)',
#  'Diagnostic Aid (radiopaque medium),Radioactive Agent',
#  'Diagnostic Aid (radiopaque medium); Radioactive Agent',
#  'Diagnostic Aid (radiopaque medium, cardiac perfusion); Radioactive Agent',
#  'Diagnostic Aid (radiopaque medium, cholecystographic)',
#  'Diagnostic Aid (renal function determination)',
#  'Diagnostic Aid (renal function determination); Diuretic',
#  'Diagnostic Aid (renal function determination); Radioactive Agent',
#  'Diagnostic Aid (renal function determination); Radioactive Agent,Radioactive Agent,Radioactive Agent; Diagnostic Aid (renal function determination)',
#  'Diagnostic Aid (thyroid function determination); Radioactive Agent',
#  'Diagnostic Aid (thyroid function determination); Radioactive Agent,Diagnostic Aid (thyroid function determination); Radioactive Agent; Antineoplastic,Radioactive Agent; Diagnostic Aid (thyroid function determination),Supplement (iodine)',
#  'Diagnostic Aid (thyroid function determination); Radioactive Agent; Antineoplastic',
#  'Diagnostic Aid (vascular patency); Radioactive Agent',
#  'Diagnostic Aid; Growth Hormone-Releasing Hormone',
#  'Diagnostic Aid; Radioactive Agent',
#  'Diagnostic Aid; Radioactive Agent; Gas, Medicinal',
#  'Diagnostic Aid; Radioactive Agent; Gas, Medicinal,Radioactive Agent',
#  'Disinfectant',
#  'Disinfectant,Pharmaceutic Aid (preservative)',
#  'Diuretic',
#  'Diuretic; Aldosterone Antagonist',
#  'Diuretic; Antihypertensive',
#  'Diuretic; Uricosuric; Antihypertensive',
#  'Dopamine Agonist',
#  'Dopamine Agonist; Antidyskinetic; Antihyperprolactinemic',
#  'Dopamine Agonist; Antihypertensive',
#  'Dusting Powder; Pharmaceutic Aid',
#  'Ectoparasiticide',
#  'Emetic',
#  'Enzyme (digestant adjunct)',
#  'Enzyme (proteolytic)',
#  'Enzyme Inhibitor',
#  'Enzyme Inhibitor (angiotensin-converting)',
#  'Enzyme Inhibitor (angiotensin-converting); Antihypertensive',
#  'Enzyme Inhibitor (influenza virus neuraminidase); Antiviral',
#  'Enzyme Inhibitor (prolactin)',
#  'Enzyme Inhibitor (proteinase)',
#  'Enzyme Inhibitor (urease)',
#  'Enzyme Replenisher (glucocerebrosidase)',
#  'Estrogen',
#  'Expectorant',
#  'Expectorant; Mucolytic',
#  'Fibrinolytic',
#  'Gas, Medicinal',
#  'Gases, Diluent for',
#  'Glucocorticoid',
#  'Gonad-Stimulating Principle',
#  'Gonad-Stimulating Principle; Antagonist (LHRH)',
#  'Hair Growth Stimulant (topical); Antihypertensive',
#  'Hematinic',
#  'Hematinic; Anti-Anemic',
#  'Hematopoietic Stimulant',
#  'Hematopoietic Stimulant; Antineutropenic',
#  'Hemostatic',
#  'Hemostatic (local)',
#  'Hormone (adrenocorticotropic)',
#  'Hormone (adrenocorticotropic); Glucocorticoid; Diagnostic Aid (adrenocortical insufficiency)',
#  'Hormone (antidiuretic)',
#  "Hormone (corticotropin-releasing); Diagnostic Aid (adrenocortical insufficiency); Diagnostic Aid (cushing's syndrome)",
#  'Hormone (follicle-stimulating)',
#  'Hormone (growth)',
#  'Hypoglycemic',
#  'Immunizing Agent (active)',
#  'Immunizing Agent (passive)',
#  'Immunomodulator',
#  'Immunoregulator; Antineoplastic; Biological Response Modifier',
#  'Immunosuppressant',
#  'Immunosuppressant; Antineoplastic',
#  'Impotence Therapy',
#  'Inhibitor (5-lipoxygenase)',
#  'Inhibitor (HMG-CoA reductase)',
#  'Inhibitor (HMG-CoA reductase); Antihyperlipidemic',
#  'Inhibitor (aldose reductase)',
#  'Inhibitor (alpha reductase)',
#  'Inhibitor (alpha-glucosidase)',
#  'Inhibitor (beta-lactamase)',
#  'Inhibitor (beta-lactamase); Synergist (penicillin/cephalosporin),Synergist (penicillin/cephalosporin); Inhibitor (beta-lactamase)',
#  'Inhibitor (decarboxylase)',
#  'Inhibitor (pancreatic lipase)',
#  'Inhibitor (platelet)',
#  'Inhibitor (platelet); Vasodilator; Antithrombotic',
#  'Ion-Exchange Resin (potassium)',
#  'Keratolytic',
#  'LHRH Agonist',
#  'LHRH Agonist; Antineoplastic',
#  'Laxative',
#  'Laxative; Antacid',
#  'Laxative; Pharmaceutic Aid (solvent)',
#  'Leukopheresis Adjunct (red cell sedimenting agent)',
#  'Menopausal Symptoms Suppressant',
#  'Monoclonal Antibody',
#  'Monoclonal Antibody (anti-endotoxin)',
#  'Monoclonal Antibody (antimyosin)',
#  'Monoclonal Antibody (antithrombotic)',
#  'Monoclonal Antibody (diagnostic for the detection of infectious lesions)',
#  'Monoclonal Antibody (immunosuppressant)',
#  'Monoclonal Antibody,Radioactive Agent',
#  'Monoclonal Antibody; Antineoplastic (microtubule inhibitor)',
#  'Mucolytic',
#  'Multiple Sclerosis Symptomatic Treatment',
#  'Myocardial Infarction Therapy; Plasminogen Activator',
#  'Nasal Decongestant',
#  'Neuroleptic',
#  'Neuromuscular Blocking Agent',
#  None,
#  'Nutrient',
#  "Osteoporosis Treatment And Prevention; Paget's Disease Treatment",
#  'Oxytocic',
#  'Oxytocic; Prostaglandin',
#  'Pediculicide',
#  'Pediculicide; Scabicide',
#  'Pharmaceutic Aid',
#  'Pharmaceutic Aid (acidifying agent)',
#  'Pharmaceutic Aid (air displacement)',
#  'Pharmaceutic Aid (alkalizing agent)',
#  'Pharmaceutic Aid (alkalizing agent); Analgesic',
#  'Pharmaceutic Aid (antifungal agent)',
#  'Pharmaceutic Aid (antimicrobial agent)',
#  'Pharmaceutic Aid (buffering agent)',
#  'Pharmaceutic Aid (chelating agent); Chelating Agent (metal)',
#  'Pharmaceutic Aid (dispersing and suspending agent)',
#  'Pharmaceutic Aid (emulsifying agent)',
#  'Pharmaceutic Aid (emulsifying agent); Pharmaceutic Aid (suspending agent)',
#  'Pharmaceutic Aid (emulsifying agent); Pharmaceutic Aid (tablet coating agent); Protectant (topical)',
#  'Pharmaceutic Aid (emulsifying and stiffening agent)',
#  'Pharmaceutic Aid (encapsulating agent); Pharmaceutic Aid (suspending agent); Pharmaceutic Aid (tablet binder); Pharmaceutic Aid (tablet coating agent)',
#  'Pharmaceutic Aid (flavor)',
#  'Pharmaceutic Aid (flavor); Pharmaceutic Aid (tablet excipient)',
#  'Pharmaceutic Aid (in dialysis solutions),Radioactive Agent',
#  'Pharmaceutic Aid (preservative)',
#  'Pharmaceutic Aid (solvent and source of ammonia),Radioactive Agent; Diagnostic Aid (cardiac imaging); Diagnostic Aid (liver imaging)',
#  'Pharmaceutic Aid (solvent)',
#  'Pharmaceutic Aid (solvent); Anti-Infective, Topical',
#  'Pharmaceutic Aid (solvent); Pharmaceutic Aid (humectant)',
#  'Pharmaceutic Aid (sorbent)',
#  'Pharmaceutic Aid (stabilizer)',
#  'Pharmaceutic Aid (stiffening agent); Pharmaceutic Aid (emulsifying agent)',
#  'Pharmaceutic Aid (surfactant)',
#  'Pharmaceutic Aid (suspending agent)',
#  'Pharmaceutic Aid (suspending agent); Pharmaceutic Aid (viscosity-increasing agent); Pharmaceutic Aid (tablet excipient)',
#  'Pharmaceutic Aid (suspending agent); Protectant',
#  'Pharmaceutic Aid (tablet binder); Pharmaceutic Aid (tablet and capsule diluent); Pharmaceutic Aid (viscosity-increasing agent); Pharmaceutic Aid (coating agent)',
#  'Pharmaceutic Aid (tablet disintegrant); Pharmaceutic Aid (tablet binder)',
#  'Pharmaceutic Aid (tonicity agent),Radioactive Agent',
#  'Pharmaceutic Aid (vehicle, oleaginous)',
#  'Pharmaceutic Aid (viscosity-increasing agent)',
#  'Pharmaceutic Aid (viscosity-increasing agent); Pharmaceutic Aid (suspending agent); Pharmaceutic Aid (tablet excipient)',
#  'Pharmaceutic Necessity',
#  'Pigmentation Agent',
#  'Plasma Volume Extender',
#  'Plasminogen Activator',
#  'Potentiator',
#  'Progestin',
#  'Prostaglandin',
#  'Prosthetic Aid',
#  'Prosthetic Aid (soft tissue); Lubricant And Hydrophobing Agent',
#  'Protectant (topical)',
#  'Protectant (topical); Pharmaceutic Aid (ointment base, oleaginous)',
#  'Protectant (topical); Radioprotector',
#  'Prothyrotropin',
#  'Pulmonary Surfactant',
#  'Radioactive Agent',
#  'Radioactive Agent,Replenisher (calcium)',
#  'Radioactive Agent,Replenisher (electrolyte)',
#  'Radioactive Agent,Thyroid Hormone',
#  'Radioactive Agent; Antineoplastic',
#  'Radioactive Agent; Diagnostic Aid',
#  'Radioactive Agent; Diagnostic Aid (cardiac imaging); Diagnostic Aid (liver imaging)',
#  'Radioactive Agent; Diagnostic Aid (lung imaging)',
#  'Radioactive Agent; Diagnostic Aid (pernicious anemia)',
#  'Radioactive Agent; Diagnostic Aid (radiopaque medium, cardiac perfusion)',
#  'Radioactive Agent; Diagnostic Aid (renal function determination)',
#  'Radioactive Agent; Diagnostic Aid (skeletal imaging)',
#  'Regulator (calcium)',
#  'Relaxant (muscle)',
#  'Relaxant (skeletal muscle)',
#  'Relaxant (skeletal muscle); Synergist (succinylcholine)',
#  'Relaxant (smooth muscle)',
#  'Repellant, Arthropod',
#  'Replacement Therapy (adenosine deaminase deficiency)',
#  'Replenisher (calcium)',
#  'Replenisher (carnitine)',
#  'Replenisher (electrolyte)',
#  'Replenisher (fluid and nutrient)',
#  'Replenisher (magnesium)',
#  'Replenisher Adjunct (electrolyte)',
#  'Scabicide',
#  'Sedative (pre-anesthetic)',
#  'Sedative-Hypnotic',
#  'Sedative-Hypnotic,Tranquilizer (minor)',
#  'Sedative-Hypnotic; Antipsychotic',
#  'Sedative-Hypnotic; Relaxant (muscle); Anticonvulsant',
#  'Serotonin Antagonist',
#  'Serotonin Inhibitor',
#  'Smoking Cessation Adjunct',
#  'Spermaticide; Pharmaceutic Aid (surfactant)',
#  'Spermaticide; Pharmaceutic Aid (wetting and/or solubilizing agent)',
#  'Steroid (topical)',
#  'Stimulant (cardiac)',
#  'Stimulant (central and respiratory)',
#  'Stimulant (central)',
#  'Stimulant (gastric secretory)',
#  'Stimulant (peristaltic)',
#  'Stimulant (respiratory)',
#  'Stool Softener,Stool Softener; Pharmaceutic Aid (surfactant)',
#  'Stool Softener; Pharmaceutic Aid (surfactant)',
#  'Sunscreen',
#  'Supplement (calcium)',
#  'Supplement (iodine); Expectorant; Antifungal',
#  'Supplement (trace mineral)',
#  'Suppressant (dermatitis herpetiformis)',
#  'Suppressant (gout)',
#  'Suppressant (inflammatory bowel disease); Anti-Inflammatory (nonsteroidal)',
#  'Synergist (penicillin/cephalosporin); Inhibitor (beta-lactamase)',
#  'Thyroid Hormone',
#  'Thyroid Inhibitor',
#  'Tranquilizer',
#  'Tranquilizer (minor)',
#  'Treatment of Unstable Angina',
#  'Ultraviolet Screen',
#  'Uricosuric',
#  'Vasodilator',
#  'Vasodilator (coronary)',
#  'Vasodilator (peripheral)',
#  'Vasodilator (peripheral); Cardiac Depressant; Miotic; Cholinergic',
#  'Vitamin',
#  'Vitamin (anti-xerophthalmic)',
#  'Vitamin (antirachitic)',
#  'Vitamin (antiscorbutic)',
#  'Vitamin (enzyme co-factor)',
#  'Vitamin (enzyme co-factor); Antihyperlipidemic',
#  'Vitamin (hematopoietic)',
#  'Vitamin (prothrombogenic)',
#  'Vitamin E Supplement',
#  'Vitamins A And D, source of',
#  'Xanthine Oxidase Inhibitor'}

# %%
# Starting the DB
conn = sqlite3.connect('project.db')
c = conn.cursor()

# %%
# Creating the tables
c.execute('''CREATE TABLE IF NOT EXISTS molecule
             (chirality INT, id TEXT  PRIMARY KEY, logd REAL, logp REAL, most_apka REAL,
             most_bpka REAL, alogp REAL, aromatic_rings INT, formula TEXT, mw REAL, hba INT,
             hbd INT, heavy_atoms INT, molecular_species TEXT, qed_weighted REAL)''')

c.execute('''CREATE TABLE IF NOT EXISTS indication
             (id text, indication text, FOREIGN KEY (id) REFERENCES molecule(id))''')
conn.commit()

# %%
# Reshaping the up the property data so that it can be put in a DB
properties = ['acd_logd', 'acd_logp', 'acd_most_apka', 'acd_most_bpka', 'alogp', 'aromatic_rings',
'full_molformula', 'full_mwt', 'hba', 'hbd', 'heavy_atoms', 'molecular_species', 'qed_weighted']
mol_data = list()
for e in approved_mols:
    if  e['molecule_properties'] is None: 
        # Some of the data has no Molecular Properties, imputing this would give the average case
        # It is not useful data to keep
        continue
    mol_props = list()
    for p in properties:
        mol_props.append(e['molecule_properties'][p])
    
    entry = [e['chirality'], e['molecule_chembl_id']]
    entry = entry + mol_props
    mol_data.append(entry)
# Out:
# [['2',
#   'CHEMBL2',
#   '2.08',
#   '2.14',
#   None,
#   '6.52',
#   '1.78',
#   3,
#   'C19H21N5O4',
#   '383.41',
#   8,
#   1,
#   28,
#   'NEUTRAL',
#   '0.73'],
#  ['1',
#   'CHEMBL3',
#   '-0.62',
#   '0.57',
#   None,
#   '8',
#   '1.85',
#   1,
#   'C10H14N2',
#   '162.24',
#   2,
#   0,
#   12,
#   'NEUTRAL',
#   '0.63'],
#  ['0',
#   'CHEMBL4',
#   '-0.39',
#   '1.85',
#   '5.19',
#   '7.37',
#   '1.54',
#   2,
#   'C18H20FN3O4',
#   '361.37',
#   6,
#   1,
#   26,
#   'ACID',
#   '0.87'],
#  ['2',
#   'CHEMBL5',
#   '-1.54',
#   '0.03',
#   '3.45',
#   '6.12',
#   '1.42',
#   2,
#   'C12H12N2O3',
#   '232.24',
#   4,
#   1,
#   17,
#   'ACID',
#   '0.85'],
#  ['2',
#   'CHEMBL6',
#   '0.98',
#   '4.25',
#   '3.96',
#   None,
#   '3.93',
#   3,
#   'C19H16ClNO4',
#   '357.79',
#   4,
#   1,
#   25,
#   'ACID',
#   '0.77'],
#  ['1',
#   'CHEMBL403',
#   '-3.33',
#   '0.39',
#   '2.62',
#   None,
#   '-0.79',
#   0,
#   'C8H11NO5S',
#   '233.24',
#   4,
#   1,
#   15,
#   'ACID',
#   '0.6'],
#  ['1',
#   'CHEMBL404',
#   '-3.13',
#   '0.6',
#   '2.33',
#   '0.85',
#   '-1.52',
#   1,
#   'C10H12N4O5S',
#   '300.3',
#   7,
#   1,
#   20,
#   'ACID',
#   '0.67'],
#  ['2',
#   'CHEMBL8',
#   '-0.29',
#   '1.62',
#   '6.43',
#   '8.68',
#   '1.58',
#   2,
#   'C17H18FN3O3',
#   '331.35',
#   5,
#   2,
#   24,
#   'ZWITTERION',
#   '0.89'],
#  ['2',
#   'CHEMBL9',
#   '-0.66',
#   '1.74',
#   '0.16',
#   '8.68',
#   '1.27',
#   2,
#   'C16H18FN3O3',
#   '319.34',
#   5,
#   2,
#   23,
#   'ZWITTERION',
#   '0.89'],
#  ['0',
#   'CHEMBL405',
#   '-0.65',
#   '1.79',
#   None,
#   '9.94',
#   '1.58',
#   1,
#   'C9H13N',
#   '135.21',
#   1,
#   1,
#   10,
#   'BASE',
#   '0.65'],
#  ['1',
#   'CHEMBL6622',
#   '0.95',
#   '0.95',
#   None,
#   None,
#   '-1.06',
#   0,
#   'C6H8N2O8',
#   '236.14',
#   8,
#   0,
#   16,
#   None,
#   '0.45'],
#  ['0',
#   'CHEMBL6437',
#   '0.77',
#   '1.14',
#   None,
#   '8.26',
#   '3.08',
#   2,
#   'C18H20N2',
#   '264.37',
#   2,
#   0,
#   20,
#   'NEUTRAL',
#   '0.72'],
#  ['2',
#   'CHEMBL11',
#   '2.35',
#   '4.36',
#   None,
#   '9.49',
#   '3.88',
#   2,
#   'C19H24N2',
#   '280.42',
#   2,
#   0,
#   21,
#   'BASE',
#   '0.84'],
#  ['0',
#   'CHEMBL406',
#   '1.96',
#   '1.96',
#   '9.35',
#   '1.87',
#   '2.08',
#   2,
#   'C16H16ClN3O3S',
#   '365.84',
#   4,
#   2,
#   24,
#   'NEUTRAL',
#   '0.87'],
#  ['2',
#   'CHEMBL407',
#   '2.15',
#   '2.15',
#   None,
#   '0.86',
#   '1.77',
#   2,
#   'C15H14FN3O3',
#   '303.29',
#   5,
#   0,
#   22,
#   'NEUTRAL',
#   '0.79'],
#  ['0',
#   'CHEMBL408',
#   '3.65',
#   '4.69',
#   '6.34',
#   None,
#   '4.37',
#   2,
#   'C24H27NO5S',
#   '441.55',
#   6,
#   2,
#   31,
#   'ACID',
#   '0.72'],
#  ['0',
#   'CHEMBL409',
#   '4.13',
#   '4.13',
#   '11.49',
#   None,
#   '2.88',
#   2,
#   'C18H14F4N2O4S',
#   '430.38',
#   5,
#   2,
#   29,
#   'NEUTRAL',
#   '0.56'],
#  ['2',
#   'CHEMBL12',
#   '2.8',
#   '2.8',
#   None,
#   '3.4',
#   '3.15',
#   2,
#   'C16H13ClN2O',
#   '284.75',
#   2,
#   0,
#   20,
#   'NEUTRAL',
#   '0.79'],
#  ['0',
#   'CHEMBL13',
#   '-0.47',
#   '1.63',
#   '13.89',
#   '9.43',
#   '1.61',
#   1,
#   'C15H25NO3',
#   '267.37',
#   4,
#   2,
#   19,
#   'BASE',
#   '0.71'],
#  ['2',
#   'CHEMBL411',
#   '5.33',
#   '5.33',
#   '10.19',
#   None,
#   '4.83',
#   2,
#   'C18H20O2',
#   '268.36',
#   2,
#   2,
#   20,
#   'NEUTRAL',
#   '0.78'],
#  ['0',
#   'CHEMBL267936',
#   '-0.07',
#   '2.98',
#   None,
#   '11.35',
#   '2.42',
#   0,
#   'C11H21N',
#   '167.3',
#   1,
#   1,
#   12,
#   'BASE',
#   '0.63'],
#  ['2',
#   'CHEMBL14',
#   '-4.1',
#   '-4.1',
#   '12.54',
#   None,
#   '-0.21',
#   0,
#   'C6H15ClN2O2',
#   '182.65',
#   2,
#   1,
#   10,
#   'NEUTRAL',
#   '0.56'],
#  ['2',
#   'CHEMBL16',
#   '-0.71',
#   '1.74',
#   '1.84',
#   '10.79',
#   '1.97',
#   2,
#   'C15H12N2O2',
#   '252.27',
#   2,
#   2,
#   19,
#   'ZWITTERION',
#   '0.86'],
#  ['1',
#   'CHEMBL413',
#   '4.26',
#   '4.26',
#   '10.4',
#   None,
#   '6.18',
#   0,
#   'C51H79NO13',
#   '914.19',
#   13,
#   3,
#   65,
#   'NEUTRAL',
#   '0.16'],
#  ['1',
#   'CHEMBL269732',
#   '4.78',
#   '4.79',
#   '9.96',
#   None,
#   '4.64',
#   0,
#   'C44H69NO12',
#   '804.03',
#   12,
#   3,
#   57,
#   'NEUTRAL',
#   '0.18'],
#  ['2',
#   'CHEMBL415',
#   '2.95',
#   '4.94',
#   None,
#   '9.46',
#   '4.53',
#   2,
#   'C19H23ClN2',
#   '314.86',
#   2,
#   0,
#   22,
#   'BASE',
#   '0.82'],
#  ['2',
#   'CHEMBL416',
#   '1.52',
#   '1.52',
#   None,
#   None,
#   '2.55',
#   3,
#   'C12H8O4',
#   '216.19',
#   4,
#   0,
#   16,
#   None,
#   '0.59'],
#  ['2',
#   'CHEMBL17',
#   '0.32',
#   '0.34',
#   '8.95',
#   None,
#   '0.29',
#   1,
#   'C6H6Cl2N2O4S2',
#   '305.16',
#   4,
#   2,
#   16,
#   'NEUTRAL',
#   '0.82'],
#  ['2',
#   'CHEMBL18',
#   '2.12',
#   '2.14',
#   '8.41',
#   None,
#   '1.34',
#   2,
#   'C9H10N2O3S2',
#   '258.32',
#   5,
#   1,
#   16,
#   'NEUTRAL',
#   '0.9'],
#  ['1',
#   'CHEMBL417',
#   '-1.47',
#   '0.24',
#   '7.35',
#   '8.68',
#   '0',
#   2,
#   'C27H29NO11',
#   '543.53',
#   12,
#   6,
#   39,
#   'BASE',
#   '0.24'],
#  ['2',
#   'CHEMBL19',
#   '-0.21',
#   '0.13',
#   '7.31',
#   None,
#   '-1.42',
#   1,
#   'C5H8N4O3S2',
#   '236.28',
#   6,
#   1,
#   14,
#   'NEUTRAL',
#   '0.64'],
#  ['2',
#   'CHEMBL20',
#   '-0.69',
#   '-0.26',
#   '7.44',
#   None,
#   '-0.86',
#   1,
#   'C4H6N4O3S2',
#   '222.25',
#   6,
#   2,
#   13,
#   'NEUTRAL',
#   '0.63'],
#  ['2',
#   'CHEMBL419',
#   '-1.52',
#   '-0.38',
#   '10.16',
#   '8.52',
#   '-0.21',
#   1,
#   'C7H10N2O2S',
#   '186.24',
#   3,
#   2,
#   12,
#   'BASE',
#   '0.67'],
#  ['2',
#   'CHEMBL21',
#   '-0.67',
#   '-0.67',
#   '10.1',
#   '1.85',
#   '-0.08',
#   1,
#   'C6H8N2O2S',
#   '172.21',
#   3,
#   2,
#   11,
#   'NEUTRAL',
#   '0.58'],
#  ['2',
#   'CHEMBL420',
#   '1.85',
#   '2.66',
#   None,
#   '8.17',
#   '1.81',
#   1,
#   'C8H8Cl2N4',
#   '231.09',
#   2,
#   3,
#   14,
#   'NEUTRAL',
#   '0.41'],
#  ['2',
#   'CHEMBL22',
#   '0.47',
#   '0.59',
#   None,
#   '6.9',
#   '1.26',
#   2,
#   'C14H18N4O3',
#   '290.32',
#   7,
#   2,
#   21,
#   'NEUTRAL',
#   '0.85'],
#  ['0',
#   'CHEMBL6966',
#   '2.46',
#   '4.02',
#   None,
#   '8.97',
#   '5.09',
#   2,
#   'C27H38N2O4',
#   '454.61',
#   6,
#   0,
#   33,
#   'BASE',
#   '0.42'],
#  ['2',
#   'CHEMBL421',
#   '-0.1',
#   '3.05',
#   '2.88',
#   '0.75',
#   '3.7',
#   3,
#   'C18H14N4O5S',
#   '398.4',
#   7,
#   3,
#   28,
#   'ACID',
#   '0.54'],
#  ['2',
#   'CHEMBL6466',
#   '1.39',
#   '1.39',
#   None,
#   None,
#   '1.79',
#   2,
#   'C9H6O2',
#   '146.14',
#   2,
#   0,
#   11,
#   None,
#   '0.53'],
#  ['1',
#   'CHEMBL23',
#   '3.36',
#   '4.73',
#   None,
#   '8.94',
#   '3.37',
#   2,
#   'C22H26N2O4S',
#   '414.53',
#   6,
#   0,
#   29,
#   'BASE',
#   '0.68'],
#  ['0',
#   'CHEMBL24',
#   '-1.76',
#   '0.34',
#   '13.88',
#   '9.43',
#   '0.45',
#   1,
#   'C14H22N2O3',
#   '266.34',
#   4,
#   3,
#   19,
#   'BASE',
#   '0.64'],
#  ['2',
#   'CHEMBL25',
#   '-1.68',
#   '1.4',
#   '3.48',
#   None,
#   '1.31',
#   1,
#   'C9H8O4',
#   '180.16',
#   3,
#   1,
#   13,
#   'ACID',
#   '0.55'],
#  ['2',
#   'CHEMBL422',
#   '4.02',
#   '4.62',
#   None,
#   '7.66',
#   '4.95',
#   2,
#   'C21H24F3N3S',
#   '407.51',
#   4,
#   0,
#   28,
#   'NEUTRAL',
#   '0.71'],
#  ['0',
#   'CHEMBL26',
#   '-1.07',
#   '0.78',
#   '9.98',
#   '8.97',
#   '0.56',
#   1,
#   'C15H23N3O4S',
#   '341.43',
#   5,
#   2,
#   23,
#   'BASE',
#   '0.79'],
#  ['0',
#   'CHEMBL423',
#   '0.43',
#   '2.53',
#   '13.89',
#   '9.43',
#   '2.39',
#   1,
#   'C18H29NO3',
#   '307.43',
#   4,
#   2,
#   22,
#   'BASE',
#   '0.62'],
#  ['2',
#   'CHEMBL424',
#   '-1.14',
#   '2.01',
#   '3.01',
#   None,
#   '1.09',
#   1,
#   'C7H6O3',
#   '138.12',
#   2,
#   2,
#   10,
#   'ACID',
#   '0.61'],
#  ['2',
#   'CHEMBL425',
#   '-0.58',
#   '3.57',
#   '2.73',
#   None,
#   '2.91',
#   2,
#   'C14H10N2O6',
#   '302.24',
#   6,
#   4,
#   22,
#   'ACID',
#   '0.64'],
#  ['0',
#   'CHEMBL27',
#   '0.79',
#   '2.9',
#   '13.84',
#   '9.5',
#   '2.58',
#   2,
#   'C16H21NO2',
#   '259.35',
#   3,
#   2,
#   19,
#   'BASE',
#   '0.84'],
#  ['0',
#   'CHEMBL6995',
#   '-1.5',
#   '0.59',
#   '13.88',
#   '9.43',
#   '1.38',
#   1,
#   'C14H22N2O3',
#   '266.34',
#   4,
#   3,
#   19,
#   'BASE',
#   '0.7'],
#  ['2',
#   'CHEMBL427',
#   '0.87',
#   '0.91',
#   None,
#   '6.4',
#   '1.4',
#   0,
#   'C5H11Cl2N',
#   '156.06',
#   1,
#   0,
#   8,
#   'NEUTRAL',
#   '0.56'],
#  ['1',
#   'CHEMBL29',
#   '-1.81',
#   '1.92',
#   '2.45',
#   None,
#   '0.86',
#   1,
#   'C16H18N2O4S',
#   '334.4',
#   4,
#   2,
#   23,
#   'ACID',
#   '0.8'],
#  ['1',
#   'CHEMBL428',
#   '-1.06',
#   '1',
#   '5.8',
#   '7.92',
#   '1.89',
#   3,
#   'C20H15F3N4O3',
#   '416.36',
#   6,
#   2,
#   30,
#   'ACID',
#   '0.68'],
#  ['2',
#   'CHEMBL30',
#   '-0.36',
#   '-0.07',
#   None,
#   '7.07',
#   '0.6',
#   1,
#   'C10H16N6S',
#   '252.35',
#   4,
#   3,
#   17,
#   'NEUTRAL',
#   '0.23'],
#  ['0',
#   'CHEMBL31',
#   '-0.15',
#   '2.1',
#   '6.43',
#   '8.71',
#   '1.98',
#   2,
#   'C19H22FN3O4',
#   '375.4',
#   6,
#   2,
#   27,
#   'ZWITTERION',
#   '0.85'],
#  ['0',
#   'CHEMBL429',
#   '0.83',
#   '2.72',
#   '8.21',
#   '9.3',
#   '2.14',
#   2,
#   'C19H24N2O3',
#   '328.41',
#   4,
#   4,
#   24,
#   'BASE',
#   '0.6'],
#  ['1',
#   'CHEMBL32',
#   '0.31',
#   '2.83',
#   '6.43',
#   '10.63',
#   '2.37',
#   2,
#   'C21H24FN3O4',
#   '401.44',
#   6,
#   2,
#   29,
#   'ZWITTERION',
#   '0.82'],
#  ['1',
#   'CHEMBL33',
#   '-0.39',
#   '1.85',
#   '5.19',
#   '7.37',
#   '1.54',
#   2,
#   'C18H20FN3O4',
#   '361.37',
#   6,
#   1,
#   26,
#   'ACID',
#   '0.87'],
#  ['0',
#   'CHEMBL430',
#   '-0.71',
#   '1.77',
#   '6.02',
#   '9.15',
#   '0.97',
#   2,
#   'C18H20FN5O4',
#   '389.39',
#   8,
#   2,
#   28,
#   'ZWITTERION',
#   '0.73'],
#  ['1',
#   'CHEMBL431',
#   '2.24',
#   '5.88',
#   '2.99',
#   '5.29',
#   '2.39',
#   1,
#   'C22H30N2O5S2',
#   '466.63',
#   7,
#   2,
#   31,
#   'ACID',
#   '0.54'],
#  ['2',
#   'CHEMBL433',
#   '0.02',
#   '2.58',
#   '4.82',
#   None,
#   '2.29',
#   0,
#   'C8H15NaO2',
#   '166.2',
#   1,
#   1,
#   10,
#   'ACID',
#   '0.64'],
#  ['0',
#   'CHEMBL434',
#   '-1.55',
#   '0.32',
#   '9.6',
#   '9.26',
#   '1.13',
#   1,
#   'C11H17NO3',
#   '211.26',
#   4,
#   4,
#   15,
#   'BASE',
#   '0.56'],
#  ['2',
#   'CHEMBL435',
#   '-0.04',
#   '-0.02',
#   '8.95',
#   None,
#   '-0.35',
#   1,
#   'C7H8ClN3O4S2',
#   '297.75',
#   5,
#   3,
#   17,
#   'NEUTRAL',
#   '0.65'],
#  ['2',
#   'CHEMBL35',
#   '-0.82',
#   '2.3',
#   '3.04',
#   None,
#   '1.89',
#   2,
#   'C12H11ClN2O5S',
#   '330.75',
#   5,
#   3,
#   21,
#   'ACID',
#   '0.77'],
#  ['2',
#   'CHEMBL36',
#   '2.55',
#   '2.75',
#   None,
#   '7.17',
#   '2.52',
#   2,
#   'C12H13ClN4',
#   '248.72',
#   4,
#   2,
#   17,
#   'NEUTRAL',
#   '0.86'],
#  ['2',
#   'CHEMBL436',
#   '-0.07',
#   '3.59',
#   '3.49',
#   '0.63',
#   '3.56',
#   2,
#   'C16H14F3NO3S',
#   '357.35',
#   3,
#   1,
#   24,
#   'ACID',
#   '0.85'],
#  ['2',
#   'CHEMBL437',
#   '-0.34',
#   '0.05',
#   '7.24',
#   '2.19',
#   '1.53',
#   2,
#   'C9H9N3O2S2',
#   '255.32',
#   5,
#   2,
#   16,
#   'NEUTRAL',
#   '0.81'],
#  ['2',
#   'CHEMBL438',
#   '-0.25',
#   '0.11',
#   '7.35',
#   '1.58',
#   '1.17',
#   2,
#   'C11H12N4O2S',
#   '264.31',
#   5,
#   2,
#   18,
#   'NEUTRAL',
#   '0.81'],
#  ['2',
#   'CHEMBL439',
#   '-0.8',
#   '-0.07',
#   '6.81',
#   '1.57',
#   '0.86',
#   2,
#   'C10H10N4O2S',
#   '250.28',
#   5,
#   2,
#   17,
#   'NEUTRAL',
#   '0.79'],
#  ['0',
#   'CHEMBL440',
#   '-1.11',
#   '2.39',
#   '-3.28',
#   None,
#   '1.93',
#   0,
#   'C12H18N2O2S',
#   '254.35',
#   2,
#   2,
#   17,
#   'ACID',
#   '0.45'],
#  ['0',
#   'CHEMBL441',
#   '2.59',
#   '3.05',
#   '7.11',
#   None,
#   '1.35',
#   0,
#   'C11H18N2O2S',
#   '242.34',
#   3,
#   2,
#   16,
#   'NEUTRAL',
#   '0.58'],
#  ['2',
#   'CHEMBL268164',
#   '1.41',
#   '1.5',
#   '8.03',
#   None,
#   '1.25',
#   0,
#   'C12H16N2O3',
#   '236.27',
#   3,
#   2,
#   17,
#   'NEUTRAL',
#   '0.56'],
#  ['1',
#   'CHEMBL442',
#   '7.24',
#   '7.37',
#   '9.62',
#   '6.94',
#   '1.99',
#   3,
#   'C33H35N5O5',
#   '581.67',
#   6,
#   3,
#   43,
#   'NEUTRAL',
#   '0.43'],
#  ['2',
#   'CHEMBL38',
#   '3.62',
#   '6.26',
#   '4.73',
#   None,
#   '5.6',
#   0,
#   'C20H28O2',
#   '300.44',
#   1,
#   1,
#   22,
#   'ACID',
#   '0.53'],
#  ['0',
#   'CHEMBL7413',
#   '1.88',
#   '2.01',
#   '7.82',
#   None,
#   '1.31',
#   0,
#   'C14H18N2O3',
#   '262.31',
#   3,
#   1,
#   19,
#   'NEUTRAL',
#   '0.47'],
#  ['2',
#   'CHEMBL40',
#   '0.31',
#   '0.53',
#   '7.58',
#   None,
#   '0.7',
#   1,
#   'C12H12N2O3',
#   '232.24',
#   3,
#   2,
#   17,
#   'NEUTRAL',
#   '0.74'],
#  ['0',
#   'CHEMBL41',
#   '1.41',
#   '3.93',
#   None,
#   '10.05',
#   '4.44',
#   2,
#   'C17H18F3NO',
#   '309.33',
#   2,
#   1,
#   22,
#   'BASE',
#   '0.85'],
#  ['2',
#   'CHEMBL443',
#   '-0.54',
#   '0.66',
#   '5.81',
#   '1.39',
#   '1.37',
#   2,
#   'C10H11N3O3S',
#   '253.28',
#   5,
#   2,
#   17,
#   'ACID',
#   '0.8'],
#  ['2',
#   'CHEMBL444',
#   '0.69',
#   '0.8',
#   '7.92',
#   None,
#   '0.16',
#   0,
#   'C8H12N2O3',
#   '184.19',
#   3,
#   2,
#   13,
#   'NEUTRAL',
#   '0.6'],
#  ['2',
#   'CHEMBL42',
#   '3.53',
#   '3.94',
#   None,
#   '7.33',
#   '3.72',
#   2,
#   'C18H19ClN4',
#   '326.83',
#   4,
#   1,
#   23,
#   'NEUTRAL',
#   '0.8'],
#  ['2',
#   'CHEMBL445',
#   '1.49',
#   '3.97',
#   None,
#   '10',
#   '3.83',
#   2,
#   'C19H21N',
#   '263.38',
#   1,
#   1,
#   20,
#   'BASE',
#   '0.83'],
#  ['2',
#   'CHEMBL446',
#   '0.15',
#   '0.3',
#   '7.89',
#   '1.08',
#   '1.48',
#   2,
#   'C12H14N4O2S',
#   '278.34',
#   5,
#   2,
#   19,
#   'NEUTRAL',
#   '0.83'],
#  ['0',
#   'CHEMBL447',
#   '2.16',
#   '2.3',
#   '7.81',
#   None,
#   '1.35',
#   0,
#   'C12H18N2O3',
#   '238.29',
#   3,
#   2,
#   17,
#   'NEUTRAL',
#   '0.56'],
#  ['0',
#   'CHEMBL448',
#   '2.06',
#   '2.18',
#   '7.93',
#   None,
#   '1.18',
#   0,
#   'C11H18N2O3',
#   '226.28',
#   3,
#   2,
#   16,
#   'NEUTRAL',
#   '0.71'],
#  ['0',
#   'CHEMBL267894',
#   '0.14',
#   '2.01',
#   '7.69',
#   None,
#   '1.39',
#   0,
#   'C11H18N2O3',
#   '226.28',
#   2,
#   2,
#   16,
#   'NEUTRAL',
#   '0.71'],
#  ['0',
#   'CHEMBL449',
#   '1.56',
#   '1.67',
#   '7.93',
#   None,
#   '0.79',
#   0,
#   'C10H16N2O3',
#   '212.25',
#   3,
#   2,
#   15,
#   'NEUTRAL',
#   '0.68'],
#  ['2',
#   'CHEMBL450',
#   '1.45',
#   '1.5',
#   '8.27',
#   None,
#   '0.5',
#   0,
#   'C9H14N2O3',
#   '198.22',
#   3,
#   1,
#   14,
#   'NEUTRAL',
#   '0.66'],
#  ['2',
#   'CHEMBL451',
#   '2.49',
#   '2.49',
#   None,
#   '2.38',
#   '2.95',
#   2,
#   'C16H14ClN3O',
#   '299.76',
#   3,
#   1,
#   21,
#   'NEUTRAL',
#   '0.65'],
#  ['2',
#   'CHEMBL452',
#   '2.52',
#   '2.52',
#   '11.21',
#   '1.55',
#   '3.04',
#   2,
#   'C15H10ClN3O3',
#   '315.72',
#   4,
#   1,
#   22,
#   'NEUTRAL',
#   '0.68'],
#  ['2',
#   'CHEMBL453',
#   '-0.55',
#   '1.01',
#   '4.83',
#   '1.52',
#   '1.67',
#   2,
#   'C11H13N3O3S',
#   '267.31',
#   5,
#   2,
#   18,
#   'ACID',
#   '0.82'],
#  ['2',
#   'CHEMBL268869',
#   '-0.45',
#   '0.32',
#   '7.19',
#   '3.54',
#   '0.87',
#   2,
#   'C11H12N4O3S',
#   '280.31',
#   6,
#   2,
#   19,
#   'NEUTRAL',
#   '0.8'],
#  ['2',
#   'CHEMBL454',
#   '1.64',
#   '1.79',
#   '7.78',
#   None,
#   '0.96',
#   0,
#   'C11H16N2O3',
#   '224.26',
#   3,
#   2,
#   16,
#   'NEUTRAL',
#   '0.55'],
#  ['2',
#   'CHEMBL455',
#   '-2.52',
#   '-0.96',
#   '5.43',
#   '0.93',
#   '0.09',
#   1,
#   'C8H10N2O3S',
#   '214.25',
#   4,
#   2,
#   14,
#   'ACID',
#   '0.68'],
#  ['2',
#   'CHEMBL43',
#   '3.22',
#   '3.32',
#   '8.55',
#   '7.89',
#   '4.51',
#   4,
#   'C21H19N3O3S',
#   '393.47',
#   5,
#   2,
#   28,
#   'NEUTRAL',
#   '0.49'],
#  ['2',
#   'CHEMBL456',
#   '-0.85',
#   '2.84',
#   '2.81',
#   None,
#   '3.61',
#   1,
#   'C13H12Cl2O4',
#   '303.14',
#   3,
#   1,
#   19,
#   'ACID',
#   '0.64'],
#  ['2',
#   'CHEMBL267744',
#   '-0.65',
#   '3.04',
#   '2.79',
#   None,
#   '3.75',
#   2,
#   'C13H8Cl2O4S',
#   '331.18',
#   4,
#   1,
#   20,
#   'ACID',
#   '0.85'],
#  ['2',
#   'CHEMBL457',
#   '1.69',
#   '4.3',
#   '4.75',
#   None,
#   '3.57',
#   1,
#   'C15H22O3',
#   '250.34',
#   2,
#   1,
#   18,
#   'ACID',
#   '0.78'],
#  ['2',
#   'CHEMBL45',
#   '1.04',
#   '1.04',
#   None,
#   None,
#   '1.86',
#   2,
#   'C13H16N2O2',
#   '232.28',
#   2,
#   2,
#   17,
#   'NEUTRAL',
#   '0.84'],
#  ['0',
#   'CHEMBL46',
#   '1.2',
#   '1.55',
#   None,
#   '7.5',
#   '3.13',
#   3,
#   'C18H19N3O',
#   '293.37',
#   4,
#   0,
#   22,
#   'NEUTRAL',
#   '0.73'],
#  ['2',
#   'CHEMBL49',
#   '1.24',
#   '1.59',
#   None,
#   '7.72',
#   '2.09',
#   1,
#   'C21H31N5O2',
#   '385.51',
#   6,
#   0,
#   28,
#   'NEUTRAL',
#   '0.55'],
#  ['2',
#   'CHEMBL51',
#   '3.05',
#   '3.56',
#   '12.83',
#   '7.8',
#   '2.42',
#   3,
#   'C22H22FN3O3',
#   '395.43',
#   5,
#   1,
#   29,
#   'NEUTRAL',
#   '0.67'],
#  ['1',
#   'CHEMBL459',
#   '-3.26',
#   '-0.74',
#   '2.28',
#   '8.85',
#   '0.44',
#   1,
#   'C10H13NO4',
#   '211.22',
#   4,
#   4,
#   15,
#   'ZWITTERION',
#   '0.54'],
#  ['0',
#   'CHEMBL460',
#   '-1.38',
#   '-1.32',
#   None,
#   '6.57',
#   '1.96',
#   1,
#   'C16H24N2O2',
#   '276.38',
#   3,
#   1,
#   20,
#   'NEUTRAL',
#   '0.92'],
#  ['1',
#   'CHEMBL53',
#   '1.16',
#   '1.7',
#   '9.43',
#   '7.88',
#   '2.85',
#   2,
#   'C17H17NO2',
#   '267.33',
#   3,
#   2,
#   20,
#   'NEUTRAL',
#   '0.72'],
#  ['2',
#   'CHEMBL54',
#   '2.93',
#   '3.76',
#   '13.86',
#   '8.04',
#   '4.43',
#   2,
#   'C21H23ClFNO2',
#   '375.87',
#   3,
#   1,
#   26,
#   'NEUTRAL',
#   '0.76'],
#  ['2',
#   'CHEMBL55',
#   '-0.15',
#   '2.85',
#   None,
#   '12.5',
#   '2.88',
#   2,
#   'C19H24N4O2',
#   '340.43',
#   4,
#   4,
#   25,
#   'BASE',
#   '0.3'],
#  ['2',
#   'CHEMBL463',
#   '-3.69',
#   '-0.12',
#   '3.61',
#   '2.53',
#   '0.08',
#   1,
#   'C9H10N2O3',
#   '194.19',
#   3,
#   3,
#   14,
#   'ACID',
#   '0.59'],
#  ['2',
#   'CHEMBL464',
#   '7.15',
#   '7.15',
#   None,
#   None,
#   '5.65',
#   1,
#   'C23H30O3',
#   '354.49',
#   3,
#   0,
#   26,
#   None,
#   '0.36'],
#  ['2',
#   'CHEMBL57',
#   '2.64',
#   '2.64',
#   '12.05',
#   '4.25',
#   '2.65',
#   2,
#   'C15H14N4O',
#   '266.3',
#   4,
#   1,
#   20,
#   'NEUTRAL',
#   '0.86'],
#  ['1',
#   'CHEMBL465',
#   '6.84',
#   '6.84',
#   '9.81',
#   None,
#   '5.74',
#   1,
#   'C21H30O2',
#   '314.47',
#   2,
#   1,
#   23,
#   'NEUTRAL',
#   '0.57'],
#  ['2',
#   'CHEMBL58',
#   '-1.58',
#   '1.55',
#   '7.08',
#   '9.27',
#   '-0.14',
#   2,
#   'C22H28N4O6',
#   '444.49',
#   10,
#   8,
#   32,
#   'BASE',
#   '0.14'],
#  ['2',
#   'CHEMBL59',
#   '-2.21',
#   '0.05',
#   '9.39',
#   '10.11',
#   '0.6',
#   1,
#   'C8H11NO2',
#   '153.18',
#   3,
#   3,
#   11,
#   'BASE',
#   '0.54'],
#  ['2',
#   'CHEMBL467',
#   '-1.8',
#   '-1.8',
#   '10.56',
#   None,
#   '-0.96',
#   0,
#   'CH4N2O2',
#   '76.05',
#   2,
#   3,
#   5,
#   'NEUTRAL',
#   '0.26'],
#  ['1',
#   'CHEMBL61',
#   '2.35',
#   '2.35',
#   '13.26',
#   None,
#   '2.41',
#   2,
#   'C22H22O8',
#   '414.41',
#   8,
#   1,
#   30,
#   'NEUTRAL',
#   '0.76'],
#  ['2',
#   'CHEMBL64',
#   '-0.77',
#   '-0.77',
#   '11.4',
#   '3.79',
#   '-0.31',
#   1,
#   'C6H7N3O',
#   '137.14',
#   3,
#   2,
#   10,
#   'NEUTRAL',
#   '0.32'],
#  ['0',
#   'CHEMBL468',
#   '0.33',
#   '0.33',
#   '10.7',
#   None,
#   '0.09',
#   1,
#   'C13H10N2O4',
#   '258.23',
#   4,
#   1,
#   19,
#   'NEUTRAL',
#   '0.72'],
#  ['0',
#   'CHEMBL469',
#   '-0.34',
#   '2.68',
#   '4.29',
#   None,
#   '2.29',
#   2,
#   'C15H13NO3',
#   '255.27',
#   3,
#   1,
#   19,
#   'ACID',
#   '0.86'],
#  ['0',
#   'CHEMBL471',
#   '-1.68',
#   '0.24',
#   '8.28',
#   '9.31',
#   '1.09',
#   1,
#   'C12H20N2O3S',
#   '272.37',
#   4,
#   3,
#   18,
#   'BASE',
#   '0.72'],
#  ['2',
#   'CHEMBL472',
#   '1.14',
#   '3.08',
#   '5.11',
#   None,
#   '3.64',
#   2,
#   'C23H28ClN3O5S',
#   '494.01',
#   5,
#   3,
#   33,
#   'ACID',
#   '0.52'],
#  ['2',
#   'CHEMBL473',
#   '0.52',
#   '1.38',
#   '8.98',
#   '8.28',
#   '1.98',
#   2,
#   'C19H27N3O5S2',
#   '441.58',
#   6,
#   2,
#   29,
#   'NEUTRAL',
#   '0.55'],
#  ['2',
#   'CHEMBL476',
#   '0.03',
#   '0.03',
#   '11.45',
#   '3.93',
#   '0.07',
#   1,
#   'C6H10N6O',
#   '182.19',
#   4,
#   2,
#   13,
#   'NEUTRAL',
#   '0.51'],
#  ['1',
#   'CHEMBL477',
#   '-0.76',
#   '-0.76',
#   '13.11',
#   '3.82',
#   '-1.98',
#   2,
#   'C10H13N5O4',
#   '267.25',
#   9,
#   4,
#   19,
#   'NEUTRAL',
#   '0.49'],
#  ['0',
#   'CHEMBL479',
#   '3.5',
#   '5.9',
#   None,
#   '9.84',
#   '5.89',
#   2,
#   'C21H26N2S2',
#   '370.59',
#   4,
#   0,
#   25,
#   'BASE',
#   '0.62'],
#  ['0',
#   'CHEMBL480',
#   '2.58',
#   '2.58',
#   '9.56',
#   '3.65',
#   '3.52',
#   3,
#   'C16H14F3N3O2S',
#   '369.37',
#   4,
#   1,
#   25,
#   'NEUTRAL',
#   '0.75'],
#  ['1',
#   'CHEMBL481',
#   '2.08',
#   '3.73',
#   '11.2',
#   '9.33',
#   '4.09',
#   3,
#   'C33H38N4O6',
#   '586.69',
#   9,
#   1,
#   43,
#   'BASE',
#   '0.36'],
#  ['1',
#   'CHEMBL70',
#   '0.04',
#   '0.87',
#   '9.48',
#   '8.25',
#   '1.2',
#   1,
#   'C17H19NO3',
#   '285.34',
#   4,
#   2,
#   21,
#   'NEUTRAL',
#   '0.7'],
#  ['1',
#   'CHEMBL485',
#   '0.46',
#   '1.39',
#   '13.4',
#   '8.23',
#   '1.5',
#   1,
#   'C18H21NO3',
#   '299.37',
#   4,
#   1,
#   22,
#   'NEUTRAL',
#   '0.8'],
#  ['2',
#   'CHEMBL71',
#   '3.24',
#   '5.18',
#   None,
#   '9.41',
#   '4.89',
#   2,
#   'C17H19ClN2S',
#   '318.87',
#   3,
#   0,
#   21,
#   'BASE',
#   '0.79'],
#  ['2',
#   'CHEMBL72',
#   '1.27',
#   '3.97',
#   None,
#   '10.4',
#   '3.53',
#   2,
#   'C18H22N2',
#   '266.39',
#   2,
#   1,
#   20,
#   'BASE',
#   '0.85'],
#  ['0',
#   'CHEMBL488',
#   '0.54',
#   '0.54',
#   '11.6',
#   '4.41',
#   '1.35',
#   1,
#   'C13H16N2O2',
#   '232.28',
#   3,
#   2,
#   17,
#   'NEUTRAL',
#   '0.6'],
#  ['2',
#   'CHEMBL74',
#   '-2.75',
#   '2',
#   '1.94',
#   None,
#   '2.11',
#   4,
#   'C23H14Na2O11',
#   '512.33',
#   9,
#   3,
#   34,
#   'ACID',
#   '0.35'],
#  ['0',
#   'CHEMBL76',
#   '1.59',
#   '4.41',
#   None,
#   '10.47',
#   '4.81',
#   2,
#   'C18H26ClN3',
#   '319.88',
#   3,
#   1,
#   22,
#   'BASE',
#   '0.76'],
#  ['1',
#   'CHEMBL490',
#   '1.48',
#   '3.7',
#   None,
#   '9.68',
#   '3.33',
#   2,
#   'C19H20FNO3',
#   '329.37',
#   4,
#   1,
#   24,
#   'BASE',
#   '0.93'],
#  ['2',
#   'CHEMBL416146',
#   '2.46',
#   '2.46',
#   None,
#   '3.68',
#   '4.18',
#   3,
#   'C18H15ClN2O2S',
#   '358.85',
#   4,
#   0,
#   24,
#   'NEUTRAL',
#   '0.7'],
#  ['2',
#   'CHEMBL79',
#   '1.67',
#   '2.2',
#   None,
#   '7.96',
#   '2.58',
#   1,
#   'C14H22N2O',
#   '234.34',
#   2,
#   1,
#   17,
#   'NEUTRAL',
#   '0.85'],
#  ['2',
#   'CHEMBL9967',
#   '-0.07',
#   '0.21',
#   '11.29',
#   '7.39',
#   '1.56',
#   2,
#   'C19H21N5O2',
#   '351.41',
#   5,
#   1,
#   26,
#   'NEUTRAL',
#   '0.89'],
#  ['0',
#   'CHEMBL492',
#   '3.16',
#   '3.57',
#   None,
#   '8.07',
#   '3.75',
#   1,
#   'C17H28N2O',
#   '276.42',
#   2,
#   1,
#   20,
#   'NEUTRAL',
#   '0.82'],
#  ['1',
#   'CHEMBL80',
#   '1.66',
#   '1.77',
#   '9.16',
#   '6.71',
#   '1.3',
#   1,
#   'C19H21NO4',
#   '327.38',
#   5,
#   2,
#   24,
#   'NEUTRAL',
#   '0.8'],
#  ['2',
#   'CHEMBL81',
#   '3.4',
#   '4.57',
#   '8.83',
#   '8.52',
#   '6.08',
#   4,
#   'C28H27NO4S',
#   '473.59',
#   6,
#   2,
#   34,
#   'BASE',
#   '0.32'],
#  ['2',
#   'CHEMBL83',
#   '3.83',
#   '5.13',
#   None,
#   '8.69',
#   '6',
#   3,
#   'C26H29NO',
#   '371.52',
#   2,
#   0,
#   28,
#   'BASE',
#   '0.45'],
#  ['1',
#   'CHEMBL493',
#   '8.55',
#   '8.6',
#   '9.6',
#   '6.44',
#   '3.19',
#   2,
#   'C32H40BrN5O5',
#   '654.61',
#   6,
#   3,
#   43,
#   'NEUTRAL',
#   '0.46'],
#  ['0',
#   'CHEMBL494',
#   '0.68',
#   '3.28',
#   '4.77',
#   None,
#   '3.54',
#   0,
#   'C22H32O4',
#   '360.49',
#   3,
#   3,
#   26,
#   'ACID',
#   '0.35'],
#  ['1',
#   'CHEMBL84',
#   '-0.32',
#   '0.32',
#   '8.92',
#   '7.65',
#   '1.85',
#   3,
#   'C23H23N3O5',
#   '421.45',
#   8,
#   2,
#   31,
#   'NEUTRAL',
#   '0.49'],
#  ['2',
#   'CHEMBL85',
#   '1.89',
#   '2.68',
#   None,
#   '8.07',
#   '3.59',
#   3,
#   'C23H27FN4O2',
#   '410.49',
#   6,
#   0,
#   30,
#   'NEUTRAL',
#   '0.66'],
#  ['2',
#   'CHEMBL428880',
#   '-2.75',
#   '2',
#   '1.94',
#   None,
#   '2.11',
#   4,
#   'C23H16O11',
#   '468.37',
#   9,
#   3,
#   34,
#   'ACID',
#   '0.35'],
#  ['2',
#   'CHEMBL86',
#   '0.3',
#   '2.16',
#   '13.84',
#   '9.08',
#   '2',
#   1,
#   'C14H22ClN3O2',
#   '299.8',
#   4,
#   2,
#   20,
#   'BASE',
#   '0.76'],
#  ['1',
#   'CHEMBL428647',
#   '3.95',
#   '3.95',
#   '11.9',
#   None,
#   '3.74',
#   3,
#   'C47H51NO14',
#   '853.92',
#   14,
#   4,
#   62,
#   'NEUTRAL',
#   '0.13'],
#  ['1',
#   'CHEMBL495',
#   '0.16',
#   '2.75',
#   '4.77',
#   None,
#   '3.48',
#   0,
#   'C20H34O5',
#   '354.49',
#   4,
#   3,
#   25,
#   'ACID',
#   '0.35'],
#  ['2',
#   'CHEMBL496',
#   '5.81',
#   '7.17',
#   '6.49',
#   None,
#   '6.61',
#   2,
#   'C13H6Cl6O2',
#   '406.91',
#   2,
#   2,
#   21,
#   'ACID',
#   '0.55'],
#  ['2',
#   'CHEMBL497',
#   '2.47',
#   '4.17',
#   '2.32',
#   '7.23',
#   '3.2',
#   2,
#   'C9H5ClINO',
#   '305.5',
#   2,
#   1,
#   13,
#   'ACID',
#   '0.76'],
#  ['2',
#   'CHEMBL10878',
#   '2.46',
#   '2.46',
#   None,
#   None,
#   '2.53',
#   2,
#   'C15H17NO2',
#   '243.31',
#   2,
#   1,
#   18,
#   'NEUTRAL',
#   '0.9'],
#  ['0',
#   'CHEMBL88',
#   '0.73',
#   '0.73',
#   None,
#   '2.84',
#   '1.88',
#   0,
#   'C7H15Cl2N2O2P',
#   '261.09',
#   2,
#   1,
#   14,
#   'NEUTRAL',
#   '0.61'],
#  ['2',
#   'CHEMBL498',
#   '0.32',
#   '2.29',
#   '4.71',
#   None,
#   '1.74',
#   1,
#   'C10H13ClN2O3S',
#   '276.75',
#   3,
#   2,
#   17,
#   'ACID',
#   '0.88'],
#  ['1',
#   'CHEMBL499',
#   '-0.6',
#   '1.28',
#   '13.38',
#   '9.35',
#   '0.5',
#   1,
#   'C13H24N4O3S',
#   '316.43',
#   8,
#   2,
#   21,
#   'BASE',
#   '0.79'],
#  ['0',
#   'CHEMBL500',
#   '-0.5',
#   '1.68',
#   '13.94',
#   '9.54',
#   '1.91',
#   2,
#   'C14H20N2O2',
#   '248.33',
#   3,
#   3,
#   18,
#   'BASE',
#   '0.73'],
#  ['2',
#   'CHEMBL11359',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'H6Cl2N2Pt+2',
#   '300.05',
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['2',
#   'CHEMBL276832',
#   '0.99',
#   '1',
#   None,
#   '6.25',
#   '0.92',
#   2,
#   'C8H8N4',
#   '160.18',
#   4,
#   2,
#   12,
#   'NEUTRAL',
#   '0.48'],
#  ['0',
#   'CHEMBL501',
#   '-0.65',
#   '1.79',
#   None,
#   '9.94',
#   '1.58',
#   1,
#   'C9H15NO4S',
#   '233.29',
#   1,
#   1,
#   10,
#   'BASE',
#   '0.65'],
#  ['1',
#   'CHEMBL267345',
#   '-0.28',
#   '2.3',
#   '3.72',
#   '8.12',
#   '0.71',
#   0,
#   'C47H73NO17',
#   '924.09',
#   17,
#   12,
#   65,
#   'ACID',
#   '0.17'],
#  ['2',
#   'CHEMBL90',
#   '-2.7',
#   '-0.7',
#   None,
#   '9.26',
#   '-0.09',
#   1,
#   'C5H9N3',
#   '111.15',
#   2,
#   2,
#   8,
#   'BASE',
#   '0.56'],
#  ['0',
#   'CHEMBL91',
#   '4.9',
#   '4.97',
#   None,
#   '6.64',
#   '6.45',
#   3,
#   'C18H14Cl4N2O',
#   '416.14',
#   3,
#   0,
#   25,
#   'NEUTRAL',
#   '0.46'],
#  ['1',
#   'CHEMBL92',
#   '2.46',
#   '2.46',
#   '11.2',
#   None,
#   '3.26',
#   2,
#   'C43H53NO14',
#   '807.89',
#   14,
#   5,
#   58,
#   'NEUTRAL',
#   '0.15'],
#  ['0',
#   'CHEMBL93',
#   '2.7',
#   '2.7',
#   '9.97',
#   None,
#   '2.73',
#   2,
#   'C11H12N2O2S',
#   '236.3',
#   3,
#   2,
#   16,
#   'NEUTRAL',
#   '0.62'],
#  ['1',
#   'CHEMBL94',
#   '0.54',
#   '1.27',
#   '12.23',
#   '8.31',
#   '1.77',
#   1,
#   'C15H21N3O2',
#   '275.35',
#   4,
#   1,
#   20,
#   'NEUTRAL',
#   '0.85'],
#  ['2',
#   'CHEMBL95',
#   '0.51',
#   '2.56',
#   None,
#   '9.64',
#   '2.7',
#   2,
#   'C13H14N2',
#   '198.27',
#   2,
#   1,
#   15,
#   'BASE',
#   '0.71'],
#  ['0',
#   'CHEMBL502',
#   '2.47',
#   '3.91',
#   None,
#   '8.84',
#   '4.36',
#   2,
#   'C24H29NO3',
#   '379.5',
#   4,
#   0,
#   28,
#   'BASE',
#   '0.75'],
#  ['1',
#   'CHEMBL503',
#   '4.31',
#   '4.31',
#   '13.49',
#   None,
#   '4.2',
#   0,
#   'C24H36O5',
#   '404.55',
#   5,
#   1,
#   29,
#   'NEUTRAL',
#   '0.67'],
#  ['2',
#   'CHEMBL12610',
#   '1.65',
#   '3.56',
#   None,
#   '9.25',
#   '3.42',
#   3,
#   'C19H23N3O',
#   '309.41',
#   4,
#   0,
#   23,
#   'BASE',
#   '0.63'],
#  ['2',
#   'CHEMBL504',
#   '-1.41',
#   '-1.41',
#   None,
#   None,
#   '-0.01',
#   0,
#   'C2H6OS',
#   '78.14',
#   1,
#   0,
#   4,
#   None,
#   '0.4'],
#  ['0',
#   'CHEMBL505',
#   '1.03',
#   '2.97',
#   None,
#   '9.33',
#   '3.82',
#   2,
#   'C16H19ClN2',
#   '274.8',
#   2,
#   0,
#   19,
#   'BASE',
#   '0.82'],
#  ['0',
#   'CHEMBL506',
#   '0.01',
#   '2.74',
#   None,
#   '10.38',
#   '2.78',
#   2,
#   'C15H21N3O',
#   '259.35',
#   4,
#   2,
#   19,
#   'BASE',
#   '0.84'],
#  ['2',
#   'CHEMBL509',
#   '2.37',
#   '5.44',
#   '3.59',
#   None,
#   '4.74',
#   2,
#   'C14H11Cl2NO2',
#   '296.15',
#   2,
#   2,
#   19,
#   'ACID',
#   '0.86'],
#  ['2',
#   'CHEMBL511',
#   '0.76',
#   '2.67',
#   None,
#   '9.02',
#   '2.66',
#   2,
#   'C17H23N3O',
#   '285.39',
#   4,
#   0,
#   21,
#   'BASE',
#   '0.78'],
#  ['2',
#   'CHEMBL12713',
#   '2.46',
#   '3.67',
#   None,
#   '8.97',
#   '4.63',
#   3,
#   'C24H26ClFN4O',
#   '440.95',
#   3,
#   1,
#   31,
#   'BASE',
#   '0.63'],
#  ['2',
#   'CHEMBL513',
#   '1.37',
#   '1.38',
#   '10.19',
#   None,
#   '1.16',
#   0,
#   'C5H9Cl2N3O2',
#   '214.05',
#   3,
#   1,
#   12,
#   'NEUTRAL',
#   '0.42'],
#  ['2',
#   'CHEMBL514',
#   '2.72',
#   '2.72',
#   '10.88',
#   None,
#   '2.25',
#   0,
#   'C9H16ClN3O2',
#   '233.7',
#   3,
#   1,
#   15,
#   'NEUTRAL',
#   '0.46'],
#  ['2',
#   'CHEMBL515',
#   '0.06',
#   '2.61',
#   '4.82',
#   '4.62',
#   '3.38',
#   1,
#   'C14H19Cl2NO2',
#   '304.22',
#   2,
#   1,
#   19,
#   'ACID',
#   '0.71'],
#  ['2',
#   'CHEMBL516',
#   '4.27',
#   '5.82',
#   None,
#   '8.95',
#   '4.7',
#   2,
#   'C21H21N',
#   '287.41',
#   1,
#   0,
#   22,
#   'BASE',
#   '0.58'],
#  ['2',
#   'CHEMBL12856',
#   '-0.22',
#   '-0.21',
#   '12.05',
#   '5.72',
#   '1.02',
#   2,
#   'C10H9N3O',
#   '187.2',
#   3,
#   2,
#   14,
#   'NEUTRAL',
#   '0.7'],
#  ['0',
#   'CHEMBL517',
#   '-0.07',
#   '2.33',
#   None,
#   '10.1',
#   '3.36',
#   2,
#   'C21H29N3O',
#   '339.48',
#   3,
#   1,
#   25,
#   'BASE',
#   '0.8'],
#  ['1',
#   'CHEMBL412873',
#   '-0.02',
#   '2.84',
#   None,
#   '10.08',
#   '2.35',
#   0,
#   'C15H26N2',
#   '234.39',
#   2,
#   0,
#   17,
#   'BASE',
#   '0.63'],
#  ['2',
#   'CHEMBL98',
#   '2.34',
#   '2.34',
#   '9.48',
#   '0.5',
#   '2.47',
#   1,
#   'C14H20N2O3',
#   '264.32',
#   3,
#   3,
#   19,
#   'NEUTRAL',
#   '0.38'],
#  ['2',
#   'CHEMBL267648',
#   '-0.17',
#   '1.92',
#   '0.16',
#   '7.41',
#   '1.61',
#   2,
#   'C17H20FN3O3',
#   '333.36',
#   5,
#   1,
#   24,
#   'ACID',
#   '0.92'],
#  ['0',
#   'CHEMBL521',
#   '0.58',
#   '3.5',
#   '4.41',
#   None,
#   '3.07',
#   1,
#   'C13H18O2',
#   '206.28',
#   1,
#   1,
#   15,
#   'ACID',
#   '0.82'],
#  ['2',
#   'CHEMBL13376',
#   '1.22',
#   '4.43',
#   '4.04',
#   None,
#   '3.93',
#   3,
#   'C19H16ClNO4',
#   '357.79',
#   4,
#   1,
#   25,
#   'ACID',
#   '0.7'],
#  ['2',
#   'CHEMBL13280',
#   '2.13',
#   '2.13',
#   None,
#   '1.68',
#   '2.55',
#   2,
#   'C16H12FN3O3',
#   '313.29',
#   4,
#   0,
#   23,
#   'NEUTRAL',
#   '0.63'],
#  ['2',
#   'CHEMBL13209',
#   '2.35',
#   '2.35',
#   '11.35',
#   '2.55',
#   '2.38',
#   2,
#   'C15H11N3O3',
#   '281.27',
#   4,
#   1,
#   21,
#   'NEUTRAL',
#   '0.68'],
#  ['0',
#   'CHEMBL524',
#   '-1.1',
#   '0.61',
#   '11.87',
#   '8.29',
#   '1.08',
#   1,
#   'C11H17NO3',
#   '211.26',
#   4,
#   2,
#   15,
#   'NEUTRAL',
#   '0.78'],
#  ['2',
#   'CHEMBL526',
#   '3.66',
#   '3.66',
#   '11',
#   None,
#   '3.64',
#   1,
#   'C12H18O',
#   '178.27',
#   1,
#   1,
#   13,
#   'NEUTRAL',
#   '0.73'],
#  ['2',
#   'CHEMBL527',
#   '-2.27',
#   '0.59',
#   '4.5',
#   '3.54',
#   '1.58',
#   2,
#   'C15H13N3O4S',
#   '331.35',
#   5,
#   2,
#   23,
#   'ACID',
#   '0.87'],
#  ['1',
#   'CHEMBL528',
#   '-4.35',
#   '-0.65',
#   '2.99',
#   '1.7',
#   '-0.56',
#   1,
#   'C13H13N5O5S2',
#   '383.41',
#   9,
#   3,
#   25,
#   'ACID',
#   '0.35'],
#  ['2',
#   'CHEMBL101',
#   '1.07',
#   '3.38',
#   '4.64',
#   None,
#   '3.79',
#   2,
#   'C19H20N2O2',
#   '308.38',
#   2,
#   0,
#   23,
#   'ACID',
#   '0.79'],
#  ['1',
#   'CHEMBL529',
#   '0.66',
#   '2.58',
#   '13.28',
#   '8.59',
#   '1.9',
#   0,
#   'C38H72N2O12',
#   '749',
#   14,
#   5,
#   52,
#   'BASE',
#   '0.24'],
#  ['1',
#   'CHEMBL530',
#   '-0.2',
#   '2.33',
#   None,
#   '9.04',
#   '1.41',
#   0,
#   'C15H23N3O3S',
#   '325.43',
#   4,
#   1,
#   22,
#   'BASE',
#   '0.48'],
#  ['1',
#   'CHEMBL531',
#   '2.5',
#   '3.9',
#   None,
#   '7.98',
#   '4.27',
#   2,
#   'C19H26N2S',
#   '314.5',
#   2,
#   1,
#   22,
#   'NEUTRAL',
#   '0.91'],
#  ['1',
#   'CHEMBL532',
#   '1.16',
#   '1.91',
#   '13.09',
#   '8.16',
#   '1.79',
#   0,
#   'C37H67NO13',
#   '733.94',
#   14,
#   5,
#   51,
#   'NEUTRAL',
#   '0.24'],
#  ['0',
#   'CHEMBL533',
#   '1.3',
#   '3.72',
#   '8.54',
#   '9.95',
#   '4.16',
#   1,
#   'C20H36N2O3S',
#   '384.59',
#   4,
#   2,
#   26,
#   'BASE',
#   '0.47'],
#  ['1',
#   'CHEMBL103',
#   '3.83',
#   '3.83',
#   None,
#   None,
#   '4.72',
#   0,
#   'C21H30O2',
#   '314.47',
#   2,
#   0,
#   23,
#   None,
#   '0.7'],
#  ['2',
#   'CHEMBL13828',
#   '4.06',
#   '4.34',
#   '12.2',
#   '7.5',
#   '4.13',
#   4,
#   'C27H30N4O',
#   '426.56',
#   4,
#   1,
#   32,
#   'NEUTRAL',
#   '0.48'],
#  ['2',
#   'CHEMBL534',
#   '0.74',
#   '2.19',
#   None,
#   '8.84',
#   '4.01',
#   2,
#   'C19H19NOS',
#   '309.43',
#   3,
#   0,
#   22,
#   'BASE',
#   '0.73'],
#  ['2',
#   'CHEMBL535',
#   '0.44',
#   '2.27',
#   '11.7',
#   '9.09',
#   '3.33',
#   2,
#   'C22H27FN4O2',
#   '398.48',
#   3,
#   3,
#   29,
#   'BASE',
#   '0.63'],
#  ['2',
#   'CHEMBL537',
#   '0.62',
#   '0.62',
#   '10.33',
#   None,
#   '1.1',
#   1,
#   'C6H6O2',
#   '110.11',
#   2,
#   2,
#   8,
#   'NEUTRAL',
#   '0.49'],
#  ['2',
#   'CHEMBL539',
#   '-2.9',
#   '-0.32',
#   '4.79',
#   None,
#   '0.09',
#   0,
#   'C2H4O2',
#   '60.05',
#   1,
#   1,
#   4,
#   'ACID',
#   '0.43'],
#  ['2',
#   'CHEMBL541',
#   '-1.31',
#   '1.56',
#   '4.2',
#   None,
#   '1.38',
#   1,
#   'C7H6O2',
#   '122.12',
#   1,
#   1,
#   9,
#   'ACID',
#   '0.61'],
#  ['2',
#   'CHEMBL542',
#   '-1.76',
#   '0.68',
#   '4.86',
#   '2.51',
#   '0.97',
#   1,
#   'C7H7NO2',
#   '137.14',
#   2,
#   2,
#   10,
#   'ACID',
#   '0.57'],
#  ['2',
#   'CHEMBL14053',
#   '-2.02',
#   '1.73',
#   '0.09',
#   None,
#   '1.44',
#   0,
#   'C2HCl3O2',
#   '163.39',
#   1,
#   1,
#   7,
#   'ACID',
#   '0.55'],
#  ['2',
#   'CHEMBL14060',
#   '1.54',
#   '1.54',
#   '9.86',
#   None,
#   '1.39',
#   1,
#   'C6H6O',
#   '94.11',
#   1,
#   1,
#   7,
#   'NEUTRAL',
#   '0.51'],
#  ['2',
#   'CHEMBL544',
#   '1.35',
#   '1.35',
#   '10.4',
#   None,
#   '1.4',
#   1,
#   'C7H8O2',
#   '124.14',
#   2,
#   1,
#   9,
#   'NEUTRAL',
#   '0.61'],
#  ['2',
#   'CHEMBL104',
#   '4.9',
#   '4.92',
#   None,
#   '6.12',
#   '5.38',
#   4,
#   'C22H17ClN2',
#   '344.85',
#   2,
#   0,
#   25,
#   'NEUTRAL',
#   '0.45'],
#  ['1',
#   'CHEMBL105',
#   '-0.3',
#   '-0.3',
#   '13.27',
#   '5.08',
#   '-1.65',
#   0,
#   'C15H18N4O5',
#   '334.33',
#   8,
#   3,
#   24,
#   'NEUTRAL',
#   '0.41'],
#  ['2',
#   'CHEMBL545',
#   '-0.18',
#   '-0.18',
#   None,
#   None,
#   '0',
#   0,
#   'C2H6O',
#   '46.07',
#   1,
#   1,
#   3,
#   'NEUTRAL',
#   '0.41'],
#  ['0',
#   'CHEMBL546',
#   '0.04',
#   '2.15',
#   '13.89',
#   '9.44',
#   '1.99',
#   1,
#   'C15H23NO3',
#   '265.35',
#   4,
#   2,
#   19,
#   'BASE',
#   '0.67'],
#  ['2',
#   'CHEMBL106',
#   '0.45',
#   '0.45',
#   '11.01',
#   '2.94',
#   '0.74',
#   3,
#   'C13H12F2N6O',
#   '306.28',
#   7,
#   1,
#   22,
#   'NEUTRAL',
#   '0.75'],
#  ['2',
#   'CHEMBL547',
#   '3.66',
#   '6.26',
#   '4.76',
#   None,
#   '5.6',
#   0,
#   'C20H28O2',
#   '300.44',
#   1,
#   1,
#   22,
#   'ACID',
#   '0.53'],
#  ['2',
#   'CHEMBL14376',
#   '2.31',
#   '3.38',
#   None,
#   '8.43',
#   '4.83',
#   3,
#   'C24H27FN2O4',
#   '426.49',
#   6,
#   0,
#   31,
#   'NEUTRAL',
#   '0.38'],
#  ['1',
#   'CHEMBL548',
#   '0.36',
#   '2.97',
#   '4.75',
#   None,
#   '3.25',
#   0,
#   'C20H32O5',
#   '352.47',
#   4,
#   3,
#   25,
#   'ACID',
#   '0.37'],
#  ['2',
#   'CHEMBL278020',
#   '-2.09',
#   '-2.09',
#   None,
#   None,
#   '1.94',
#   1,
#   'C12H19N2O2+',
#   '223.3',
#   2,
#   0,
#   16,
#   'NEUTRAL',
#   '0.72'],
#  ['0',
#   'CHEMBL14370',
#   '1.44',
#   '2.45',
#   None,
#   '8.38',
#   '3.19',
#   2,
#   'C19H23NO3',
#   '313.4',
#   4,
#   1,
#   23,
#   'NEUTRAL',
#   '0.89'],
#  ['0',
#   'CHEMBL549',
#   '1.35',
#   '3.48',
#   None,
#   '9.57',
#   '3.81',
#   2,
#   'C20H21FN2O',
#   '324.4',
#   3,
#   0,
#   24,
#   'BASE',
#   '0.84'],
#  ['1',
#   'CHEMBL550',
#   '-0.39',
#   '-0.24',
#   None,
#   '7.01',
#   '1.16',
#   1,
#   'C11H16N2O2',
#   '208.26',
#   4,
#   0,
#   15,
#   'NEUTRAL',
#   '0.7'],
#  ['1',
#   'CHEMBL107',
#   '1.07',
#   '1.07',
#   None,
#   None,
#   '2.87',
#   2,
#   'C22H25NO6',
#   '399.44',
#   6,
#   1,
#   29,
#   'NEUTRAL',
#   '0.83'],
#  ['2',
#   'CHEMBL553',
#   '3.03',
#   '3.03',
#   None,
#   '5.32',
#   '3.41',
#   3,
#   'C22H23N3O4',
#   '393.44',
#   7,
#   1,
#   29,
#   'NEUTRAL',
#   '0.42'],
#  ['2',
#   'CHEMBL554',
#   '6.26',
#   '6.3',
#   None,
#   '6.34',
#   '6.14',
#   5,
#   'C29H26ClFN4O4S',
#   '581.07',
#   8,
#   2,
#   40,
#   'NEUTRAL',
#   '0.18'],
#  ['2',
#   'CHEMBL15023',
#   '3.09',
#   '3.79',
#   '13.87',
#   '7.88',
#   '4.79',
#   2,
#   'C22H23F4NO2',
#   '409.42',
#   3,
#   1,
#   29,
#   'NEUTRAL',
#   '0.55'],
#  ['2',
#   'CHEMBL108',
#   '1.9',
#   '1.9',
#   '13.94',
#   None,
#   '3.39',
#   2,
#   'C15H12N2O',
#   '236.27',
#   1,
#   1,
#   18,
#   'NEUTRAL',
#   '0.75'],
#  ['1',
#   'CHEMBL15245',
#   '1.72',
#   '2.87',
#   None,
#   '8.44',
#   '2.65',
#   2,
#   'C21H26N2O3',
#   '354.45',
#   4,
#   2,
#   26,
#   'NEUTRAL',
#   '0.77'],
#  ['2',
#   'CHEMBL109',
#   '0.02',
#   '2.58',
#   '4.82',
#   None,
#   '2.29',
#   0,
#   'C8H16O2',
#   '144.21',
#   1,
#   1,
#   10,
#   'ACID',
#   '0.64'],
#  ['0',
#   'CHEMBL277100',
#   '-0.88',
#   '1.27',
#   '6.02',
#   '8.74',
#   '2.9',
#   3,
#   'C21H18F3N3O3',
#   '417.39',
#   5,
#   2,
#   30,
#   'ZWITTERION',
#   '0.69'],
#  ['2',
#   'CHEMBL110',
#   '0.91',
#   '0.91',
#   None,
#   '0.45',
#   '1.11',
#   2,
#   'C12H12N4O3',
#   '260.25',
#   5,
#   1,
#   19,
#   'NEUTRAL',
#   '0.64'],
#  ['2',
#   'CHEMBL556',
#   '-3.4',
#   '-0.61',
#   '9.08',
#   '10.56',
#   '0.92',
#   0,
#   'C25H48N6O8',
#   '560.69',
#   9,
#   6,
#   39,
#   'BASE',
#   '0.06'],
#  ['0',
#   'CHEMBL558',
#   '0.92',
#   '2.12',
#   None,
#   '8.58',
#   '2.03',
#   1,
#   'C11H17NO',
#   '179.26',
#   2,
#   1,
#   13,
#   'BASE',
#   '0.77'],
#  ['1',
#   'CHEMBL559',
#   '1.68',
#   '4.72',
#   '2.12',
#   '8.27',
#   '4.56',
#   2,
#   'C15H11I4NO4',
#   '776.87',
#   4,
#   3,
#   24,
#   'ACID',
#   '0.39'],
#  ['2',
#   'CHEMBL111',
#   '4.84',
#   '4.84',
#   '11.31',
#   '3.22',
#   '5.94',
#   3,
#   'C22H21Cl3N4O',
#   '463.8',
#   4,
#   1,
#   30,
#   'NEUTRAL',
#   '0.52'],
#  ['0',
#   'CHEMBL273575',
#   '0.32',
#   '1.01',
#   None,
#   '7.85',
#   '2.85',
#   2,
#   'C16H18N2',
#   '238.33',
#   2,
#   1,
#   18,
#   'NEUTRAL',
#   '0.77'],
#  ['0',
#   'CHEMBL561',
#   '0.04',
#   '2.46',
#   '-0.25',
#   '8.57',
#   '1.8',
#   2,
#   'C17H19F2N3O3',
#   '351.35',
#   5,
#   2,
#   25,
#   'ZWITTERION',
#   '0.88'],
#  ['1',
#   'CHEMBL562',
#   '2.01',
#   '2.01',
#   None,
#   None,
#   '2.81',
#   1,
#   'C17H17ClO6',
#   '352.77',
#   6,
#   0,
#   24,
#   None,
#   '0.83'],
#  ['0',
#   'CHEMBL563',
#   '0.52',
#   '3.66',
#   '4.14',
#   None,
#   '3.68',
#   2,
#   'C15H13FO2',
#   '244.26',
#   1,
#   1,
#   18,
#   'ACID',
#   '0.89'],
#  ['2',
#   'CHEMBL564',
#   '2.73',
#   '4.69',
#   None,
#   '9.43',
#   '4.24',
#   2,
#   'C17H20N2S',
#   '284.43',
#   3,
#   0,
#   20,
#   'BASE',
#   '0.83'],
#  ['2',
#   'CHEMBL565',
#   '3.88',
#   '3.88',
#   None,
#   None,
#   '3.06',
#   1,
#   'C12H15ClO3',
#   '242.7',
#   3,
#   0,
#   16,
#   None,
#   '0.76'],
#  ['2',
#   'CHEMBL112',
#   '0.47',
#   '0.47',
#   '9.86',
#   '1.72',
#   '1.35',
#   1,
#   'C8H9NO2',
#   '151.16',
#   2,
#   2,
#   11,
#   'NEUTRAL',
#   '0.6'],
#  ['2',
#   'CHEMBL277522',
#   '0.32',
#   '3.12',
#   '4.55',
#   None,
#   '3.4',
#   2,
#   'C16H14O3',
#   '254.28',
#   2,
#   1,
#   19,
#   'ACID',
#   '0.83'],
#  ['2',
#   'CHEMBL113',
#   '-0.63',
#   '-0.63',
#   None,
#   '0.52',
#   '-1.03',
#   2,
#   'C8H10N4O2',
#   '194.19',
#   6,
#   0,
#   14,
#   'NEUTRAL',
#   '0.54'],
#  ['2',
#   'CHEMBL16073',
#   '1.66',
#   '1.66',
#   None,
#   '1.42',
#   '2.04',
#   1,
#   'C10H13NO2',
#   '179.22',
#   2,
#   1,
#   13,
#   'NEUTRAL',
#   '0.77'],
#  ['2',
#   'CHEMBL567',
#   '3.6',
#   '3.94',
#   None,
#   '7.39',
#   '3.94',
#   2,
#   'C21H26ClN3OS',
#   '403.98',
#   5,
#   1,
#   27,
#   'NEUTRAL',
#   '0.79'],
#  ['0',
#   'CHEMBL568',
#   '2.21',
#   '2.22',
#   '10.94',
#   '1.17',
#   '2.45',
#   2,
#   'C15H11ClN2O2',
#   '286.72',
#   3,
#   2,
#   20,
#   'NEUTRAL',
#   '0.85'],
#  ['1',
#   'CHEMBL15770',
#   '-0.49',
#   '2.55',
#   '4.26',
#   None,
#   '4.37',
#   2,
#   'C20H17FO3S',
#   '356.42',
#   2,
#   1,
#   25,
#   'ACID',
#   '0.89'],
#  ['2',
#   'CHEMBL15677',
#   '1.41',
#   '4.59',
#   '4.08',
#   None,
#   '4.41',
#   2,
#   'C14H10Cl2O3',
#   '297.14',
#   2,
#   1,
#   19,
#   'ACID',
#   '0.91'],
#  ['2',
#   'CHEMBL416898',
#   '6.32',
#   '6.32',
#   None,
#   None,
#   '6.5',
#   2,
#   'C14H9Cl5',
#   '354.49',
#   0,
#   0,
#   19,
#   None,
#   '0.54'],
#  ['2',
#   'CHEMBL276520',
#   '0.18',
#   '3.06',
#   None,
#   '10.69',
#   '3.1',
#   2,
#   'C15H20N2',
#   '228.34',
#   1,
#   2,
#   17,
#   'BASE',
#   '0.83'],
#  ['2',
#   'CHEMBL569',
#   '0.42',
#   '2.26',
#   None,
#   '9.24',
#   '1.77',
#   1,
#   'C13H20N2O2',
#   '236.31',
#   4,
#   1,
#   17,
#   'BASE',
#   '0.6'],
#  ['2',
#   'CHEMBL570',
#   '3.22',
#   '5.16',
#   None,
#   '9.4',
#   '5.26',
#   2,
#   'C18H19F3N2S',
#   '352.43',
#   3,
#   0,
#   24,
#   'BASE',
#   '0.74'],
#  ['0',
#   'CHEMBL571',
#   '-0.16',
#   '2.91',
#   '4.23',
#   None,
#   '3.11',
#   2,
#   'C16H14O3',
#   '254.29',
#   2,
#   1,
#   19,
#   'ACID',
#   '0.85'],
#  ['2',
#   'CHEMBL572',
#   '-0.7',
#   '-0.47',
#   '7.55',
#   None,
#   '0.07',
#   1,
#   'C8H6N4O5',
#   '238.16',
#   6,
#   1,
#   17,
#   'NEUTRAL',
#   '0.35'],
#  ['0',
#   'CHEMBL15870',
#   '-0.06',
#   '2.82',
#   '4.39',
#   '0.35',
#   '3.04',
#   2,
#   'C17H15NO3',
#   '281.31',
#   2,
#   1,
#   21,
#   'ACID',
#   '0.94'],
#  ['1',
#   'CHEMBL15891',
#   '3.82',
#   '3.82',
#   None,
#   None,
#   '3.64',
#   0,
#   'C6H6Cl6',
#   '290.83',
#   0,
#   0,
#   12,
#   None,
#   '0.6'],
#  ['2',
#   'CHEMBL573',
#   '-2.85',
#   '0.22',
#   '2.2',
#   '4.8',
#   '0.78',
#   1,
#   'C6H5NO2',
#   '123.11',
#   2,
#   1,
#   9,
#   'ACID',
#   '0.6'],
#  ['1',
#   'CHEMBL575',
#   '-2.71',
#   '1.02',
#   '2.44',
#   None,
#   '0.95',
#   1,
#   'C17H20N2O6S',
#   '380.42',
#   6,
#   2,
#   26,
#   'ACID',
#   '0.73'],
#  ['2',
#   'CHEMBL16080',
#   '2.35',
#   '2.35',
#   None,
#   None,
#   '2.38',
#   0,
#   'C2H3Cl3',
#   '133.41',
#   0,
#   0,
#   5,
#   None,
#   '0.45'],
#  ['2',
#   'CHEMBL278172',
#   '1.83',
#   '1.83',
#   None,
#   '2.51',
#   '1.45',
#   1,
#   'C9H11NO2',
#   '165.19',
#   3,
#   1,
#   12,
#   'NEUTRAL',
#   '0.53'],
#  ['1',
#   'CHEMBL577',
#   '-0.27',
#   '3.63',
#   '2.2',
#   '7.79',
#   '1.13',
#   1,
#   'C18H24N2O5',
#   '348.4',
#   4,
#   3,
#   25,
#   'ACID',
#   '0.65'],
#  ['1',
#   'CHEMBL578',
#   '-0.32',
#   '3.25',
#   '3.15',
#   '5.43',
#   '1.6',
#   1,
#   'C20H28N2O5',
#   '376.45',
#   5,
#   2,
#   27,
#   'ACID',
#   '0.64'],
#  ['0',
#   'CHEMBL580',
#   '2.38',
#   '2.38',
#   '10.8',
#   '0.17',
#   '3.1',
#   2,
#   'C15H10Cl2N2O2',
#   '321.16',
#   3,
#   2,
#   21,
#   'NEUTRAL',
#   '0.85'],
#  ['2',
#   'CHEMBL277062',
#   '2.28',
#   '2.28',
#   '11.39',
#   '2',
#   '2.63',
#   2,
#   'C14H10BrN3O',
#   '316.16',
#   3,
#   1,
#   19,
#   'NEUTRAL',
#   '0.88'],
#  ['2',
#   'CHEMBL279816',
#   '2.56',
#   '2.56',
#   None,
#   None,
#   '2.5',
#   0,
#   'C2HCl3',
#   '131.39',
#   0,
#   0,
#   5,
#   None,
#   '0.47'],
#  ['0',
#   'CHEMBL277535',
#   '4.63',
#   '4.69',
#   None,
#   '6.55',
#   '5.19',
#   4,
#   'C22H18N2',
#   '310.4',
#   2,
#   0,
#   24,
#   'NEUTRAL',
#   '0.51'],
#  ['2',
#   'CHEMBL582',
#   '0.17',
#   '0.17',
#   None,
#   None,
#   '0.39',
#   0,
#   'C3H8O',
#   '60.1',
#   1,
#   1,
#   4,
#   'NEUTRAL',
#   '0.43'],
#  ['0',
#   'CHEMBL583',
#   '0.62',
#   '2.57',
#   '6.44',
#   '8.74',
#   '2.28',
#   2,
#   'C19H22FN3O3',
#   '359.4',
#   5,
#   2,
#   26,
#   'ZWITTERION',
#   '0.88'],
#  ['1',
#   'CHEMBL114',
#   '5.05',
#   '5.08',
#   '11.05',
#   '6.29',
#   '3.09',
#   3,
#   'C38H50N6O5',
#   '670.86',
#   7,
#   5,
#   49,
#   'NEUTRAL',
#   '0.2'],
#  ['1',
#   'CHEMBL115',
#   '3.43',
#   '3.44',
#   None,
#   '5.19',
#   '2.87',
#   3,
#   'C36H47N5O4',
#   '613.8',
#   7,
#   4,
#   45,
#   'NEUTRAL',
#   '0.26'],
#  ['1',
#   'CHEMBL584',
#   '7.26',
#   '7.28',
#   '9.58',
#   '6.21',
#   '4.75',
#   2,
#   'C32H45N3O4S',
#   '567.8',
#   6,
#   4,
#   40,
#   'NEUTRAL',
#   '0.33'],
#  ['1',
#   'CHEMBL116',
#   '2.68',
#   '2.68',
#   '11.54',
#   '1.76',
#   '2.4',
#   2,
#   'C25H35N3O6S',
#   '505.64',
#   7,
#   3,
#   35,
#   'NEUTRAL',
#   '0.4'],
#  ['2',
#   'CHEMBL585',
#   '1.12',
#   '1.16',
#   None,
#   '6.19',
#   '0.83',
#   3,
#   'C12H11N7',
#   '253.27',
#   7,
#   3,
#   19,
#   'NEUTRAL',
#   '0.59'],
#  ['0',
#   'CHEMBL16476',
#   '0.85',
#   '2.77',
#   '13.91',
#   '9.26',
#   '2.87',
#   2,
#   'C15H19NO',
#   '229.32',
#   2,
#   2,
#   17,
#   'BASE',
#   '0.84'],
#  ['2',
#   'CHEMBL118',
#   '2.59',
#   '2.59',
#   '9.68',
#   None,
#   '3.51',
#   3,
#   'C17H14F3N3O2S',
#   '381.38',
#   4,
#   1,
#   26,
#   'NEUTRAL',
#   '0.75'],
#  ['2',
#   'CHEMBL119',
#   '0.73',
#   '1.76',
#   None,
#   '8.09',
#   '2.74',
#   3,
#   'C19H23N5O3',
#   '369.43',
#   8,
#   3,
#   27,
#   'NEUTRAL',
#   '0.61'],
#  ['0',
#   'CHEMBL588',
#   '0.21',
#   '2.06',
#   '8.5',
#   '9.49',
#   '2.73',
#   2,
#   'C16H16ClNO3',
#   '305.76',
#   4,
#   4,
#   21,
#   'BASE',
#   '0.61'],
#  ['2',
#   'CHEMBL589',
#   '0.49',
#   '2.49',
#   None,
#   '9.45',
#   '2.85',
#   1,
#   'C16H24N2O',
#   '260.38',
#   2,
#   1,
#   19,
#   'BASE',
#   '0.82'],
#  ['2',
#   'CHEMBL590',
#   '1.99',
#   '1.99',
#   None,
#   None,
#   '2.01',
#   1,
#   'C11H8O2',
#   '172.18',
#   2,
#   0,
#   13,
#   None,
#   '0.6'],
#  ['0',
#   'CHEMBL591',
#   '1.19',
#   '1.19',
#   '12.06',
#   None,
#   '1.51',
#   0,
#   'C7H9ClO',
#   '144.6',
#   1,
#   1,
#   9,
#   'NEUTRAL',
#   '0.58'],
#  ['0',
#   'CHEMBL17157',
#   '3.6',
#   '5.62',
#   '13.32',
#   '9.42',
#   '6.45',
#   3,
#   'C32H41NO2',
#   '471.69',
#   3,
#   2,
#   35,
#   'BASE',
#   '0.4'],
#  ['1',
#   'CHEMBL592',
#   '1.71',
#   '3.25',
#   '10.07',
#   '9.06',
#   '3.08',
#   1,
#   'C17H23NO',
#   '257.38',
#   2,
#   1,
#   19,
#   'BASE',
#   '0.77'],
#  ['2',
#   'CHEMBL593',
#   '1.77',
#   '3.53',
#   '9.02',
#   '9.17',
#   '2.72',
#   3,
#   'C22H28N6O3S',
#   '456.57',
#   6,
#   3,
#   32,
#   'BASE',
#   '0.53'],
#  ['2',
#   'CHEMBL594',
#   '1.33',
#   '2.78',
#   None,
#   '8.86',
#   '2.21',
#   2,
#   'C17H26N4O',
#   '302.42',
#   5,
#   0,
#   22,
#   'BASE',
#   '0.79'],
#  ['0',
#   'CHEMBL595',
#   '2.45',
#   '3.5',
#   '6.35',
#   '5.53',
#   '3.16',
#   2,
#   'C19H20N2O3S',
#   '356.45',
#   5,
#   1,
#   25,
#   'ACID',
#   '0.83'],
#  ['2',
#   'CHEMBL596',
#   '2.61',
#   '3.68',
#   None,
#   '8.92',
#   '4.14',
#   2,
#   'C22H28N2O',
#   '336.48',
#   2,
#   0,
#   25,
#   'BASE',
#   '0.79'],
#  ['0',
#   'CHEMBL121',
#   '1.93',
#   '3.02',
#   '6.34',
#   '6.5',
#   '2.49',
#   2,
#   'C18H19N3O3S',
#   '357.44',
#   6,
#   1,
#   25,
#   'ACID',
#   '0.82'],
#  ['0',
#   'CHEMBL17860',
#   '1.18',
#   '3.04',
#   None,
#   '9.8',
#   '2.76',
#   1,
#   'C11H12Cl2N2O',
#   '259.14',
#   3,
#   1,
#   16,
#   'BASE',
#   '0.91'],
#  ['2',
#   'CHEMBL597',
#   '2.13',
#   '4.08',
#   '9.52',
#   '10.31',
#   '2.84',
#   2,
#   'C17H19N3O',
#   '281.36',
#   4,
#   2,
#   21,
#   'BASE',
#   '0.91'],
#  ['2',
#   'CHEMBL18442',
#   '-6.88',
#   '-0.82',
#   None,
#   '10.6',
#   '0.42',
#   1,
#   'C28H54N8',
#   '502.8',
#   8,
#   6,
#   36,
#   'BASE',
#   '0.35'],
#  ['2',
#   'CHEMBL599',
#   '-0.22',
#   '2.66',
#   '4.5',
#   '3.18',
#   '1.95',
#   2,
#   'C14H13N3O4S2',
#   '351.41',
#   6,
#   2,
#   23,
#   'ACID',
#   '0.86'],
#  ['1',
#   'CHEMBL600',
#   '-4.39',
#   '-0.7',
#   '3.25',
#   None,
#   '-0.49',
#   0,
#   'C5H9NO3S',
#   '163.2',
#   3,
#   3,
#   10,
#   'ACID',
#   '0.49'],
#  ['2',
#   'CHEMBL601',
#   '-3.67',
#   '-1.05',
#   '4.13',
#   '7.37',
#   '-0.62',
#   0,
#   'C5H9NO3',
#   '131.13',
#   3,
#   2,
#   9,
#   'ACID',
#   '0.53'],
#  ['2',
#   'CHEMBL602',
#   '-1.3',
#   '0.22',
#   '8.32',
#   '10.34',
#   '-0.13',
#   0,
#   'C2H7NS',
#   '77.15',
#   2,
#   2,
#   4,
#   'BASE',
#   '0.42'],
#  ['1',
#   'CHEMBL19019',
#   '1.6',
#   '2.05',
#   '9.16',
#   '7.5',
#   '1.53',
#   1,
#   'C20H23NO4',
#   '341.41',
#   5,
#   2,
#   25,
#   'NEUTRAL',
#   '0.85'],
#  ['2',
#   'CHEMBL603',
#   '3.17',
#   '5.04',
#   '4.94',
#   '0.73',
#   '5.7',
#   4,
#   'C31H33N3O6S',
#   '575.69',
#   7,
#   2,
#   41,
#   'ACID',
#   '0.28'],
#  ['2',
#   'CHEMBL122',
#   '-0.34',
#   '-0.34',
#   None,
#   None,
#   '2.56',
#   2,
#   'C17H14O4S',
#   '314.36',
#   4,
#   0,
#   22,
#   None,
#   '0.82'],
#  ['2',
#   'CHEMBL19236',
#   '0.15',
#   '0.33',
#   None,
#   '7.11',
#   '0.82',
#   1,
#   'C9H12ClN5O',
#   '241.68',
#   6,
#   2,
#   16,
#   'NEUTRAL',
#   '0.75'],
#  ['2',
#   'CHEMBL19224',
#   '2.9',
#   '2.93',
#   None,
#   '6.32',
#   '3.86',
#   3,
#   'C20H21NO4',
#   '339.39',
#   5,
#   0,
#   25,
#   'NEUTRAL',
#   '0.68'],
#  ['-1',
#   'CHEMBL604',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CuO4S',
#   '159.61',
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['2',
#   'CHEMBL605',
#   '-0.56',
#   '1.32',
#   None,
#   '9.09',
#   '1.34',
#   1,
#   'C13H22ClN3O',
#   '271.79',
#   3,
#   2,
#   17,
#   'BASE',
#   '0.73'],
#  ['1',
#   'CHEMBL19215',
#   '3.12',
#   '3.8',
#   '12.45',
#   '8.06',
#   '4.06',
#   3,
#   'C25H29N3O2',
#   '403.53',
#   4,
#   1,
#   30,
#   'NEUTRAL',
#   '0.71'],
#  ['0',
#   'CHEMBL606',
#   '3.8',
#   '3.8',
#   '13.92',
#   None,
#   '3.95',
#   0,
#   'C22H38O5',
#   '382.54',
#   5,
#   2,
#   27,
#   'NEUTRAL',
#   '0.29'],
#  ['1',
#   'CHEMBL278623',
#   '0.52',
#   '1.42',
#   None,
#   '8.23',
#   '1.84',
#   4,
#   'C26H30N6O3',
#   '474.57',
#   4,
#   6,
#   35,
#   'NEUTRAL',
#   '0.15'],
#  ['2',
#   'CHEMBL607',
#   '1.61',
#   '2.19',
#   None,
#   '7.84',
#   '2.21',
#   1,
#   'C15H21NO2',
#   '247.34',
#   3,
#   0,
#   18,
#   'NEUTRAL',
#   '0.77'],
#  ['2',
#   'CHEMBL282052',
#   '2.5',
#   '2.5',
#   None,
#   '2.96',
#   '3',
#   3,
#   'C16H14N2O',
#   '250.3',
#   3,
#   0,
#   19,
#   'NEUTRAL',
#   '0.67'],
#  ['2',
#   'CHEMBL608',
#   '9',
#   '9',
#   '10.27',
#   None,
#   '9.91',
#   2,
#   'C31H48O2S2',
#   '516.86',
#   4,
#   2,
#   35,
#   'NEUTRAL',
#   '0.31'],
#  ['2',
#   'CHEMBL609',
#   '-6.05',
#   '-1.99',
#   None,
#   '10.05',
#   '-1.92',
#   0,
#   'C6H18N4',
#   '146.24',
#   4,
#   4,
#   10,
#   'BASE',
#   '0.32'],
#  ['2',
#   'CHEMBL19490',
#   '0.27',
#   '3.36',
#   '4.2',
#   None,
#   '2.85',
#   2,
#   'C15H14ClNO3',
#   '291.73',
#   3,
#   1,
#   20,
#   'ACID',
#   '0.88'],
#  ['0',
#   'CHEMBL611',
#   '0.74',
#   '0.8',
#   None,
#   '6.52',
#   '1.06',
#   2,
#   'C19H25N5O4',
#   '387.44',
#   8,
#   1,
#   28,
#   'NEUTRAL',
#   '0.83'],
#  ['1',
#   'CHEMBL612',
#   '-0.65',
#   '1.79',
#   None,
#   '9.94',
#   '1.58',
#   1,
#   'C9H13N',
#   '135.21',
#   1,
#   1,
#   10,
#   'BASE',
#   '0.65'],
#  ['2',
#   'CHEMBL282724',
#   '1.25',
#   '3.11',
#   '4.96',
#   None,
#   '3.96',
#   3,
#   'C18H15ClN2O6S2',
#   '454.91',
#   8,
#   1,
#   29,
#   'ACID',
#   '0.56'],
#  ['2',
#   'CHEMBL614',
#   '-0.71',
#   '-0.71',
#   '13.91',
#   '0.87',
#   '-0.42',
#   1,
#   'C5H5N3O',
#   '123.11',
#   3,
#   1,
#   9,
#   'NEUTRAL',
#   '0.55'],
#  ['1',
#   'CHEMBL282042',
#   '5.05',
#   '5.08',
#   '11.05',
#   '6.29',
#   '3.09',
#   3,
#   'C39H54N6O8S',
#   '766.96',
#   7,
#   5,
#   49,
#   'NEUTRAL',
#   '0.2'],
#  ['0',
#   'CHEMBL20883',
#   '-0.8',
#   '-0.6',
#   '7.63',
#   None,
#   '-0.02',
#   1,
#   'C8H9FN2O3',
#   '200.17',
#   4,
#   1,
#   14,
#   'NEUTRAL',
#   '0.69'],
#  ['1',
#   'CHEMBL615',
#   '-1.79',
#   '1.94',
#   '2.44',
#   None,
#   '0.7',
#   1,
#   'C16H18N2O5S',
#   '350.4',
#   5,
#   2,
#   24,
#   'ACID',
#   '0.76'],
#  ['1',
#   'CHEMBL617',
#   '-3.62',
#   '0.09',
#   '2.68',
#   None,
#   '0.59',
#   1,
#   'C16H16N2O6S2',
#   '396.45',
#   7,
#   2,
#   26,
#   'ACID',
#   '0.53'],
#  ['0',
#   'CHEMBL125',
#   '4.01',
#   '3.41',
#   '1.28',
#   None,
#   '5.68',
#   0,
#   'C21H46NO4P',
#   '407.58',
#   4,
#   0,
#   27,
#   'ACID',
#   '0.15'],
#  ['1',
#   'CHEMBL126',
#   '0.44',
#   '0.45',
#   None,
#   '5.75',
#   '1.12',
#   1,
#   'C16H20FN3O4',
#   '337.35',
#   5,
#   1,
#   24,
#   'NEUTRAL',
#   '0.89'],
#  ['0',
#   'CHEMBL620',
#   '-0.33',
#   '-0.33',
#   '11.13',
#   None,
#   '2.7',
#   2,
#   'C22H26NO3+',
#   '352.45',
#   3,
#   1,
#   26,
#   'NEUTRAL',
#   '0.68'],
#  ['1',
#   'CHEMBL127',
#   '-3.83',
#   '-1.23',
#   '4.27',
#   '8.31',
#   '-0.31',
#   0,
#   'C17H25N3O5S',
#   '383.47',
#   6,
#   3,
#   26,
#   'ACID',
#   '0.56'],
#  ['2',
#   'CHEMBL621',
#   '2.58',
#   '2.76',
#   None,
#   '7.52',
#   '2.36',
#   3,
#   'C19H22ClN5O',
#   '371.87',
#   6,
#   0,
#   26,
#   'NEUTRAL',
#   '0.69'],
#  ['0',
#   'CHEMBL622',
#   '0.44',
#   '3.42',
#   '4.31',
#   None,
#   '3.38',
#   2,
#   'C17H21NO3',
#   '287.36',
#   2,
#   2,
#   21,
#   'ACID',
#   '0.91'],
#  ['0',
#   'CHEMBL22108',
#   '1.71',
#   '3.85',
#   None,
#   '9.58',
#   '4.15',
#   2,
#   'C20H24N2',
#   '292.43',
#   2,
#   0,
#   22,
#   'BASE',
#   '0.82'],
#  ['2',
#   'CHEMBL623',
#   '3.88',
#   '4.09',
#   None,
#   '7.65',
#   '3.55',
#   3,
#   'C25H32ClN5O2',
#   '470.02',
#   7,
#   0,
#   33,
#   'NEUTRAL',
#   '0.45'],
#  ['2',
#   'CHEMBL625',
#   '2.47',
#   '2.47',
#   '10.53',
#   '3.4',
#   '2.69',
#   3,
#   'C10H7N3S',
#   '201.25',
#   3,
#   1,
#   14,
#   'NEUTRAL',
#   '0.66'],
#  ['2',
#   'CHEMBL626',
#   '4.36',
#   '5.04',
#   None,
#   '7.99',
#   '4.99',
#   3,
#   'C21H21N',
#   '287.41',
#   1,
#   0,
#   22,
#   'NEUTRAL',
#   '0.64'],
#  ['2',
#   'CHEMBL277474',
#   '0.44',
#   '0.44',
#   None,
#   '0.65',
#   '1.48',
#   2,
#   'C11H12N2O',
#   '188.23',
#   3,
#   0,
#   14,
#   'NEUTRAL',
#   '0.67'],
#  ['0',
#   'CHEMBL22097',
#   '2.35',
#   '2.35',
#   '11.6',
#   None,
#   '3.13',
#   2,
#   'C16H12Cl2N2O2',
#   '335.19',
#   3,
#   1,
#   22,
#   'NEUTRAL',
#   '0.87'],
#  ['2',
#   'CHEMBL628',
#   '-0.15',
#   '-0.15',
#   None,
#   '0.5',
#   '0.19',
#   2,
#   'C13H18N4O3',
#   '278.31',
#   7,
#   0,
#   20,
#   'NEUTRAL',
#   '0.73'],
#  ['2',
#   'CHEMBL629',
#   '2.65',
#   '4.41',
#   None,
#   '9.18',
#   '4.17',
#   2,
#   'C20H23N',
#   '277.41',
#   1,
#   0,
#   21,
#   'BASE',
#   '0.81'],
#  ['2',
#   'CHEMBL21869',
#   '4.88',
#   '5.19',
#   '7.57',
#   None,
#   '4.17',
#   2,
#   'C13H9Br2NO2',
#   '371.03',
#   2,
#   2,
#   18,
#   'NEUTRAL',
#   '0.83'],
#  ['2',
#   'CHEMBL24944',
#   '4.86',
#   '6.17',
#   '6',
#   None,
#   '4.93',
#   2,
#   'C13H8Br3NO2',
#   '449.92',
#   2,
#   2,
#   19,
#   'ACID',
#   '0.68'],
#  ['2',
#   'CHEMBL128',
#   '-1.45',
#   '0.44',
#   '11.31',
#   '9.49',
#   '1.32',
#   2,
#   'C14H21N3O2S',
#   '295.41',
#   3,
#   2,
#   20,
#   'BASE',
#   '0.84'],
#  ['0',
#   'CHEMBL631',
#   '1.37',
#   '3.35',
#   '13.82',
#   '9.31',
#   '3.24',
#   2,
#   'C21H27NO3',
#   '341.45',
#   4,
#   2,
#   25,
#   'BASE',
#   '0.49'],
#  ['1',
#   'CHEMBL632',
#   '2.03',
#   '2.03',
#   '12.13',
#   None,
#   '1.9',
#   0,
#   'C22H29FO5',
#   '392.47',
#   5,
#   3,
#   28,
#   'NEUTRAL',
#   '0.67'],
#  ['2',
#   'CHEMBL633',
#   '5.87',
#   '7.82',
#   None,
#   '9.37',
#   '6.94',
#   3,
#   'C25H29I2NO3',
#   '645.32',
#   4,
#   0,
#   31,
#   'BASE',
#   '0.17'],
#  ['2',
#   'CHEMBL634',
#   '1.81',
#   '2.16',
#   None,
#   '7.82',
#   '1.38',
#   2,
#   'C21H32N6O3',
#   '416.53',
#   8,
#   0,
#   30,
#   'NEUTRAL',
#   '0.61'],
#  ['1',
#   'CHEMBL635',
#   '1.57',
#   '1.57',
#   '12.36',
#   None,
#   '1.77',
#   0,
#   'C21H26O5',
#   '358.43',
#   5,
#   2,
#   26,
#   'NEUTRAL',
#   '0.78'],
#  ['1',
#   'CHEMBL636',
#   '0.85',
#   '2.06',
#   None,
#   '8.62',
#   '2.76',
#   1,
#   'C14H22N2O2',
#   '250.34',
#   3,
#   0,
#   18,
#   'BASE',
#   '0.82'],
#  ['0',
# ...
#   '4.81',
#   None,
#   '10.02',
#   '4.63',
#   3,
#   'C18H19NOS',
#   '297.42',
#   3,
#   1,
#   21,
#   'BASE',
#   '0.72'],
#  ['0',
#   'CHEMBL1177',
#   '0.42',
#   '0.42',
#   None,
#   '0.27',
#   '0.6',
#   1,
#   'C9H8N2O2',
#   '176.18',
#   3,
#   1,
#   13,
#   'NEUTRAL',
#   '0.68'],
#  ['2',
#   'CHEMBL119423',
#   '-4.58',
#   '-2.08',
#   '2.31',
#   '12.85',
#   '0.59',
#   0,
#   'C5H4N4S',
#   '152.18',
#   4,
#   2,
#   10,
#   'ZWITTERION',
#   '0.43'],
#  ['0',
#   'CHEMBL117785',
#   '2.88',
#   '2.93',
#   None,
#   '6.46',
#   '3.24',
#   1,
#   'C19H27NO3',
#   '317.43',
#   4,
#   0,
#   23,
#   'NEUTRAL',
#   '0.85'],
#  ['2',
#   'CHEMBL71595',
#   '-0.56',
#   '-0.56',
#   '11.65',
#   None,
#   '0.02',
#   0,
#   'H2O2',
#   '34.01',
#   2,
#   2,
#   2,
#   'NEUTRAL',
#   '0.29'],
#  ['2',
#   'CHEMBL1184',
#   '-3.4',
#   '-3.4',
#   None,
#   None,
#   '0.26',
#   0,
#   'C7H16ClNO2',
#   '181.66',
#   2,
#   0,
#   10,
#   None,
#   '0.42'],
#  ['1',
#   'CHEMBL1185',
#   '-1.47',
#   '0.46',
#   '12.57',
#   '9.52',
#   '1.92',
#   2,
#   'C16H21N3O2',
#   '287.36',
#   3,
#   2,
#   21,
#   'BASE',
#   '0.88'],
#  ['1',
#   'CHEMBL119443',
#   '2.19',
#   '2.48',
#   None,
#   '7.14',
#   '1.53',
#   2,
#   'C19H23N3O2',
#   '325.41',
#   3,
#   3,
#   24,
#   'NEUTRAL',
#   '0.8'],
#  ['0',
#   'CHEMBL120476',
#   '0.88',
#   '0.88',
#   '13.48',
#   None,
#   '5.48',
#   2,
#   'C44H50Cl2N4O2',
#   '737.82',
#   4,
#   2,
#   50,
#   'NEUTRAL',
#   '0.32'],
#  ['2',
#   'CHEMBL1187',
#   '-5.88',
#   '-1.64',
#   '1.97',
#   None,
#   '-0.93',
#   0,
#   'H3O4P',
#   '97.99',
#   1,
#   3,
#   5,
#   'ACID',
#   '0.34'],
#  ['2',
#   'CHEMBL121626',
#   '2.42',
#   '5.47',
#   '3.66',
#   None,
#   '4.09',
#   2,
#   'C14H12ClNO2',
#   '261.71',
#   2,
#   2,
#   18,
#   'ACID',
#   '0.87'],
#  ['1',
#   'CHEMBL338975',
#   '0.54',
#   '1.27',
#   '12.23',
#   '8.31',
#   '1.77',
#   1,
#   'C22H27N3O5',
#   '413.47',
#   4,
#   1,
#   20,
#   'NEUTRAL',
#   '0.85'],
#  ['2',
#   'CHEMBL121663',
#   '-1.87',
#   '-1.87',
#   None,
#   None,
#   '6.17',
#   4,
#   'C30H40Cl2N4',
#   '527.58',
#   2,
#   2,
#   34,
#   'NEUTRAL',
#   '0.21'],
#  ['2',
#   'CHEMBL1190',
#   '-3.37',
#   '-3.37',
#   None,
#   None,
#   '3.52',
#   0,
#   'C16H38N2+2',
#   '258.49',
#   0,
#   0,
#   18,
#   None,
#   '0.39'],
#  ['1',
#   'CHEMBL339427',
#   '0.47',
#   '0.77',
#   '8.82',
#   '7.68',
#   '6.7',
#   4,
#   'C37H41N2O6+',
#   '609.74',
#   7,
#   2,
#   45,
#   'NEUTRAL',
#   '0.24'],
#  ['2',
#   'CHEMBL338802',
#   '-0.76',
#   '-0.76',
#   None,
#   '1.88',
#   '-0.77',
#   1,
#   'C7H10N4O2S',
#   '214.25',
#   3,
#   3,
#   14,
#   'NEUTRAL',
#   '0.34'],
#  ['2',
#   'CHEMBL1191',
#   '-1.16',
#   '0.52',
#   '5.51',
#   '2.07',
#   '1.23',
#   2,
#   'C9H10N4O2S2',
#   '270.34',
#   6,
#   2,
#   17,
#   'ACID',
#   '0.82'],
#  ['0',
#   'CHEMBL1193',
#   '0.24',
#   '2.2',
#   None,
#   '9.36',
#   '3.17',
#   2,
#   'C16H20N2',
#   '240.35',
#   2,
#   0,
#   18,
#   'BASE',
#   '0.8'],
#  ['0',
#   'CHEMBL1194',
#   '1.61',
#   '2.03',
#   None,
#   '7.95',
#   '2.32',
#   1,
#   'C13H20N2O',
#   '220.32',
#   2,
#   2,
#   16,
#   'NEUTRAL',
#   '0.8'],
#  ['2',
#   'CHEMBL1195',
#   '0.9',
#   '2.7',
#   None,
#   '9.17',
#   '2.56',
#   1,
#   'C16H26N2O3',
#   '294.4',
#   5,
#   1,
#   21,
#   'BASE',
#   '0.56'],
#  ['2',
#   'CHEMBL1196',
#   '1.66',
#   '3.46',
#   None,
#   '9.2',
#   '2.56',
#   1,
#   'C16H26N2O3',
#   '294.39',
#   5,
#   1,
#   21,
#   'BASE',
#   '0.56'],
#  ['0',
#   'CHEMBL1197',
#   '2.03',
#   '3.65',
#   None,
#   '9.02',
#   '3.15',
#   1,
#   'C16H23NO2',
#   '261.36',
#   3,
#   1,
#   19,
#   'BASE',
#   '0.83'],
#  ['2',
#   'CHEMBL1198',
#   '2.38',
#   '2.59',
#   None,
#   '7.18',
#   '2.97',
#   1,
#   'C17H27NO3',
#   '293.41',
#   4,
#   0,
#   21,
#   'NEUTRAL',
#   '0.66'],
#  ['2',
#   'CHEMBL1200',
#   '2.71',
#   '4.5',
#   None,
#   '9.16',
#   '2.95',
#   1,
#   'C17H28N2O3',
#   '308.42',
#   5,
#   1,
#   22,
#   'BASE',
#   '0.41'],
#  ['2',
#   'CHEMBL1201',
#   '3.2',
#   '3.72',
#   None,
#   '7.62',
#   '3.47',
#   2,
#   'C23H29N3O2S2',
#   '443.64',
#   5,
#   0,
#   30,
#   'NEUTRAL',
#   '0.6'],
#  ['2',
#   'CHEMBL126224',
#   '2.84',
#   '5.02',
#   None,
#   '9.64',
#   '4.25',
#   2,
#   'C19H28N2',
#   '284.45',
#   2,
#   0,
#   21,
#   'BASE',
#   '0.81'],
#  ['2',
#   'CHEMBL127516',
#   '2.85',
#   '2.85',
#   None,
#   '2.39',
#   '2.23',
#   1,
#   'C11H15NO2',
#   '193.25',
#   3,
#   1,
#   14,
#   'NEUTRAL',
#   '0.45'],
#  ['2',
#   'CHEMBL1202',
#   '-0.29',
#   '1.62',
#   '6.43',
#   '8.68',
#   '1.58',
#   2,
#   'C17H19ClFN3O3',
#   '367.81',
#   5,
#   2,
#   24,
#   'ZWITTERION',
#   '0.89'],
#  ['1',
#   'CHEMBL1205',
#   '7.26',
#   '7.28',
#   '9.58',
#   '6.21',
#   '4.75',
#   2,
#   'C33H49N3O7S2',
#   '663.9',
#   6,
#   4,
#   40,
#   'NEUTRAL',
#   '0.33'],
#  ['0',
#   'CHEMBL1206',
#   '3.57',
#   '5.91',
#   None,
#   '9.88',
#   '5.02',
#   2,
#   'C19H24N2S',
#   '312.48',
#   3,
#   0,
#   22,
#   'BASE',
#   '0.77'],
#  ['2',
#   'CHEMBL1208',
#   '-3.25',
#   '0.49',
#   None,
#   '4.33',
#   '0.84',
#   2,
#   'C12H10N2O5',
#   '262.22',
#   6,
#   1,
#   19,
#   'NEUTRAL',
#   '0.86'],
#  ['1',
#   'CHEMBL132530',
#   '1.78',
#   '1.78',
#   '9.31',
#   None,
#   '3.97',
#   0,
#   'C19H26O3',
#   '302.41',
#   3,
#   1,
#   22,
#   'NEUTRAL',
#   '0.74'],
#  ['0',
#   'CHEMBL334966',
#   '-3.54',
#   '2.8',
#   '0.82',
#   '1.29',
#   '2.85',
#   2,
#   'C17H25Cl2F3N5O12P3S2',
#   '776.37',
#   15,
#   7,
#   44,
#   'ACID',
#   '0.05'],
#  ['0',
#   'CHEMBL1214',
#   '-3.62',
#   '1.13',
#   '2.44',
#   None,
#   '0.49',
#   1,
#   'C17H18N2O6S',
#   '378.41',
#   5,
#   3,
#   26,
#   'ACID',
#   '0.5'],
#  ['0',
#   'CHEMBL340978',
#   '1.09',
#   '3.72',
#   '4.36',
#   '0.38',
#   '4.34',
#   3,
#   'C16H12ClNO3',
#   '301.73',
#   3,
#   1,
#   21,
#   'ACID',
#   '0.78'],
#  ['1',
#   'CHEMBL1215',
#   '-1.77',
#   '0.12',
#   '9.77',
#   '9.22',
#   '0.65',
#   1,
#   'C9H13NO2',
#   '167.21',
#   3,
#   3,
#   12,
#   'BASE',
#   '0.62'],
#  ['1',
#   'CHEMBL1218',
#   '2.29',
#   '2.29',
#   None,
#   None,
#   '2.57',
#   1,
#   'C16H21NO2',
#   '259.35',
#   2,
#   1,
#   19,
#   'NEUTRAL',
#   '0.9'],
#  ['0',
#   'CHEMBL1219',
#   '2.09',
#   '2.1',
#   '9.57',
#   '4.54',
#   '2.99',
#   3,
#   'C18H21N3O3S',
#   '359.45',
#   5,
#   1,
#   25,
#   'NEUTRAL',
#   '0.63'],
#  ['2',
#   'CHEMBL1220',
#   '-0.29',
#   '-0.29',
#   None,
#   '2.3',
#   '0.53',
#   1,
#   'C8H13N3O4S',
#   '247.28',
#   6,
#   0,
#   16,
#   'NEUTRAL',
#   '0.56'],
#  ['0',
#   'CHEMBL1221',
#   '4.31',
#   '4.36',
#   None,
#   '6.55',
#   '6.52',
#   3,
#   'C18H15Cl3N2S',
#   '397.76',
#   3,
#   0,
#   24,
#   'NEUTRAL',
#   '0.47'],
#  ['0',
#   'CHEMBL135400',
#   '2.63',
#   '2.71',
#   None,
#   '6.7',
#   '1.57',
#   2,
#   'C17H17ClN6O3',
#   '388.82',
#   7,
#   0,
#   27,
#   'NEUTRAL',
#   '0.77'],
#  ['1',
#   'CHEMBL134342',
#   '-0.09',
#   '2.53',
#   '4.75',
#   None,
#   '2.79',
#   0,
#   'C8H14O2S2',
#   '206.33',
#   3,
#   1,
#   12,
#   'ACID',
#   '0.55'],
#  ['1',
#   'CHEMBL1223',
#   '-1.81',
#   '1.92',
#   '2.45',
#   None,
#   '0.86',
#   1,
#   'C16H17KN2O4S',
#   '372.49',
#   4,
#   2,
#   23,
#   'ACID',
#   '0.8'],
#  ['2',
#   'CHEMBL136478',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'C5FeN6Na2O',
#   '261.92',
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['2',
#   'CHEMBL1224',
#   '-0.11',
#   '2.41',
#   '1.99',
#   '8.88',
#   '4.02',
#   2,
#   'C22H24N2O2',
#   '348.45',
#   3,
#   1,
#   26,
#   'ZWITTERION',
#   '0.8'],
#  ['0',
#   'CHEMBL344159',
#   '4.12',
#   '4.12',
#   '13',
#   None,
#   '5.68',
#   3,
#   'C26H25ClN2O3',
#   '448.95',
#   3,
#   2,
#   32,
#   'NEUTRAL',
#   '0.54'],
#  ['0',
#   'CHEMBL1228',
#   '0.47',
#   '2.74',
#   '5.08',
#   '0.22',
#   '3.49',
#   2,
#   'C19H20N2O3',
#   '324.38',
#   3,
#   1,
#   24,
#   'ACID',
#   '0.86'],
#  ['1',
#   'CHEMBL1229',
#   '0.9',
#   '1.71',
#   None,
#   '8.81',
#   '1.29',
#   0,
#   'C16H28N2O4',
#   '312.41',
#   5,
#   2,
#   22,
#   'BASE',
#   '0.69'],
#  ['1',
#   'CHEMBL139367',
#   '-2.46',
#   '0.04',
#   '4.08',
#   '13.1',
#   '-0.14',
#   0,
#   'C15H28N4O4',
#   '328.41',
#   4,
#   6,
#   23,
#   'ZWITTERION',
#   '0.28'],
#  ['2',
#   'CHEMBL341812',
#   '0.28',
#   '3.25',
#   '4.36',
#   None,
#   '2.51',
#   1,
#   'C12H16O2',
#   '192.26',
#   1,
#   1,
#   14,
#   'ACID',
#   '0.8'],
#  ['0',
#   'CHEMBL1231',
#   '4.15',
#   '5.05',
#   '11.95',
#   '8.24',
#   '3.34',
#   1,
#   'C22H31NO3',
#   '357.49',
#   4,
#   1,
#   26,
#   'NEUTRAL',
#   '0.6'],
#  ['1',
#   'CHEMBL1232',
#   '-4.54',
#   '-0.72',
#   '4.03',
#   '7.79',
#   '0.94',
#   1,
#   'C22H24N3NaO7S',
#   '497.51',
#   7,
#   5,
#   33,
#   'ACID',
#   '0.36'],
#  ['0',
#   'CHEMBL1233',
#   '2.1',
#   '2.1',
#   '12.49',
#   None,
#   '2.02',
#   0,
#   'C12H24N2O4',
#   '260.33',
#   4,
#   2,
#   18,
#   'NEUTRAL',
#   '0.73'],
#  ['2',
#   'CHEMBL1234',
#   '-3.4',
#   '-0.61',
#   '9.08',
#   '10.56',
#   '0.92',
#   0,
#   'C26H52N6O11S',
#   '656.8',
#   9,
#   6,
#   39,
#   'BASE',
#   '0.06'],
#  ['1',
#   'CHEMBL1237',
#   '0.48',
#   '3.47',
#   '2.18',
#   '10.5',
#   '1.24',
#   1,
#   'C21H31N3O5',
#   '405.5',
#   5,
#   4,
#   29,
#   'ZWITTERION',
#   '0.38'],
#  ['2',
#   'CHEMBL1238',
#   '-3.42',
#   '1.2',
#   '4.47',
#   None,
#   '1.89',
#   0,
#   'C9H16O4',
#   '188.22',
#   2,
#   2,
#   13,
#   'ACID',
#   '0.57'],
#  ['2',
#   'CHEMBL1239',
#   '3.81',
#   '3.81',
#   None,
#   None,
#   '3.04',
#   2,
#   'C14H12O2',
#   '212.25',
#   2,
#   0,
#   16,
#   None,
#   '0.73'],
#  ['2',
#   'CHEMBL1240',
#   '-0.69',
#   '-0.69',
#   None,
#   None,
#   '4.73',
#   2,
#   'C23H30BrNO3',
#   '448.4',
#   3,
#   0,
#   27,
#   None,
#   '0.55'],
#  ['2',
#   'CHEMBL1241',
#   '0.85',
#   '2.78',
#   None,
#   '9.04',
#   '2.65',
#   2,
#   'C16H21N3',
#   '255.37',
#   3,
#   0,
#   19,
#   'BASE',
#   '0.79'],
#  ['2',
#   'CHEMBL1242',
#   '2.21',
#   '2.21',
#   None,
#   '4.49',
#   '2.66',
#   2,
#   'C11H11N5',
#   '213.24',
#   5,
#   2,
#   16,
#   'NEUTRAL',
#   '0.75'],
#  ['2',
#   'CHEMBL141305',
#   '4.66',
#   '4.66',
#   None,
#   None,
#   '5.3',
#   2,
#   'C23H24O4',
#   '364.44',
#   4,
#   0,
#   27,
#   None,
#   '0.55'],
#  ['2',
#   'CHEMBL139877',
#   '-2.57',
#   '-0.73',
#   '5.74',
#   '1.27',
#   '-0.37',
#   1,
#   'C7H9N3O3S',
#   '215.23',
#   4,
#   3,
#   14,
#   'ACID',
#   '0.58'],
#  ['2',
#   'CHEMBL1243',
#   '-0.11',
#   '1.74',
#   '4.85',
#   '1.11',
#   '1.39',
#   2,
#   'C13H12N2O3S',
#   '276.32',
#   4,
#   2,
#   19,
#   'ACID',
#   '0.83'],
#  ['0',
#   'CHEMBL142703',
#   '-0.98',
#   '0.17',
#   None,
#   '8.39',
#   '1.17',
#   0,
#   'C17H25N3O2',
#   '303.41',
#   4,
#   2,
#   22,
#   'NEUTRAL',
#   '0.82'],
#  ['0',
#   'CHEMBL1245',
#   None,
#   None,
#   None,
#   None,
#   '3.66',
#   2,
#   'C32H40N2O5S2',
#   '596.82',
#   1,
#   0,
#   26,
#   'NEUTRAL',
#   '0.6'],
#  ['1',
#   'CHEMBL139835',
#   '4.22',
#   '4.22',
#   None,
#   None,
#   '4.61',
#   0,
#   'C24H29ClO4',
#   '416.95',
#   4,
#   0,
#   29,
#   None,
#   '0.62'],
#  ['1',
#   'CHEMBL1251',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'C80H113ClN18O13',
#   '1570.35',
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['1',
#   'CHEMBL415606',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'C82H103ClN18O16',
#   '1632.29',
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['1',
#   'CHEMBL1252',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'C72H95ClN14O14',
#   '1416.09',
#   None,
#   None,
#   None,
#   None,
#   None],
#  ['2',
#   'CHEMBL1255',
#   '0.35',
#   '0.35',
#   None,
#   None,
#   '-0.18',
#   0,
#   'CH2O',
#   '30.03',
#   1,
#   0,
#   2,
#   None,
#   '0.36'],
#  ['0',
#   'CHEMBL1256',
#   '2.12',
#   '2.12',
#   None,
#   None,
#   '2.35',
#   0,
#   'C3H2ClF5O',
#   '184.49',
#   1,
#   0,
#   10,
#   None,
#   '0.47'],
#  ['2',
#   'CHEMBL142438',
#   '-0.9',
#   '-0.9',
#   None,
#   None,
#   '0.03',
#   0,
#   'N2',
#   '28.01',
#   2,
#   0,
#   2,
#   None,
#   '0.35'],
#  ['0',
#   'CHEMBL1257',
#   '2.16',
#   '2.16',
#   None,
#   None,
#   '2.35',
#   0,
#   'C3H2ClF5O',
#   '184.49',
#   1,
#   0,
#   10,
#   None,
#   '0.48'],
#  ['1',
#   'CHEMBL1259',
#   '-1.05',
#   '-1.05',
#   None,
#   None,
#   '7.45',
#   4,
#   'C40H48N2O6+2',
#   '652.83',
#   6,
#   0,
#   48,
#   None,
#   '0.21'],
#  ['2',
#   'CHEMBL1261',
#   '-6.93',
#   '-1.2',
#   '2.93',
#   None,
#   '-1.25',
#   0,
#   'C6H8O7',
#   '192.12',
#   4,
#   4,
#   13,
#   'ACID',
#   '0.43'],
#  ['0',
#   'CHEMBL144673',
#   '6.44',
#   '8.01',
#   None,
#   '8.74',
#   '4.71',
#   0,
#   'C21H45N3',
#   '339.61',
#   3,
#   1,
#   24,
#   'BASE',
#   '0.56'],
#  ['2',
#   'CHEMBL1262',
#   '6.18',
#   '6.2',
#   None,
#   '6.14',
#   '6.12',
#   3,
#   'C18H13Cl4N3O',
#   '429.13',
#   4,
#   0,
#   26,
#   'NEUTRAL',
#   '0.35'],
#  ['0',
#   'CHEMBL1263',
#   '1.79',
#   '3.71',
#   '9.99',
#   '9.26',
#   '4.11',
#   2,
#   'C25H37NO4',
#   '415.57',
#   5,
#   4,
#   30,
#   'BASE',
#   '0.31'],
#  ['2',
#   'CHEMBL1265',
#   '5.35',
#   '8.21',
#   '4.23',
#   None,
#   '6.68',
#   3,
#   'C28H28O3',
#   '412.53',
#   2,
#   1,
#   31,
#   'ACID',
#   '0.52'],
#  ['0',
#   'CHEMBL146095',
#   '3.01',
#   '3.02',
#   '13.07',
#   '5.64',
#   '3.14',
#   3,
#   'C19H17ClN2O4',
#   '372.81',
#   6,
#   3,
#   26,
#   'NEUTRAL',
#   '0.58'],
#  ['0',
#   'CHEMBL1266',
#   '0.88',
#   '2.85',
#   None,
#   '10.42',
#   '2.11',
#   1,
#   'C13H16N2',
#   '200.28',
#   2,
#   1,
#   15,
#   'BASE',
#   '0.74'],
#  ['1',
#   'CHEMBL343448',
#   '3.6',
#   '3.6',
#   '11.33',
#   None,
#   '1.43',
#   0,
#   'C24H36N4O6S2',
#   '540.71',
#   8,
#   4,
#   36,
#   'NEUTRAL',
#   '0.18'],
#  ['2',
#   'CHEMBL1271',
#   '-4.19',
#   '-4.19',
#   None,
#   None,
#   '2.64',
#   0,
#   'C15H32N2+2',
#   '240.44',
#   0,
#   0,
#   17,
#   None,
#   '0.49'],
#  ['1',
#   'CHEMBL1272',
#   '1.99',
#   '4.88',
#   '4.19',
#   '5.78',
#   '5.22',
#   2,
#   'C27H36N2O4',
#   '452.6',
#   4,
#   2,
#   33,
#   'ACID',
#   '0.52'],
#  ['2',
#   'CHEMBL1274',
#   '1.72',
#   '1.94',
#   '7.59',
#   None,
#   '2.45',
#   1,
#   'C12H10F3N3O4',
#   '317.22',
#   4,
#   1,
#   22,
#   'NEUTRAL',
#   '0.51'],
#  ['1',
#   'CHEMBL1275',
#   '2.5',
#   '3.9',
#   None,
#   '7.98',
#   '4.27',
#   2,
#   'C20H30N2O3S2',
#   '410.61',
#   2,
#   1,
#   22,
#   'NEUTRAL',
#   '0.91'],
#  ['2',
#   'CHEMBL1278',
#   '-0.85',
#   '1.15',
#   '11.52',
#   '9.3',
#   '2.07',
#   2,
#   'C17H25N3O2S',
#   '335.47',
#   3,
#   2,
#   23,
#   'BASE',
#   '0.88'],
#  ['1',
#   'CHEMBL1279',
#   '-1.92',
#   '0.93',
#   None,
#   '10.38',
#   '1.34',
#   2,
#   'C14H17N3O',
#   '243.31',
#   2,
#   3,
#   18,
#   'BASE',
#   '0.74'],
#  ['0',
#   'CHEMBL1280',
#   '2.46',
#   '4.02',
#   None,
#   '8.97',
#   '5.09',
#   2,
#   'C27H39ClN2O4',
#   '491.07',
#   6,
#   0,
#   33,
#   'BASE',
#   '0.42'],
#  ['2',
#   'CHEMBL149972',
#   '0.31',
#   '0.53',
#   '7.58',
#   None,
#   '0.7',
#   1,
#   'C12H11N2NaO3',
#   '254.22',
#   3,
#   2,
#   17,
#   'NEUTRAL',
#   '0.74'],
#  ['2',
#   'CHEMBL1282',
#   '2.89',
#   '3.01',
#   None,
#   '6.28',
#   '2.82',
#   3,
#   'C14H16N4',
#   '240.31',
#   4,
#   1,
#   18,
#   'NEUTRAL',
#   '0.75'],
#  ['1',
#   'CHEMBL1286',
#   '-0.88',
#   '-0.88',
#   None,
#   None,
#   '-0.13',
#   0,
#   'C8H14N2O2',
#   '170.21',
#   2,
#   1,
#   12,
#   'NEUTRAL',
#   '0.64'],
#  ['2',
#   'CHEMBL1289',
#   '5.53',
#   '5.53',
#   None,
#   None,
#   '4.42',
#   1,
#   'C9H4Cl3IO',
#   '361.39',
#   1,
#   0,
#   14,
#   None,
#   '0.43'],
#  ['1',
#   'CHEMBL1290',
#   '1.86',
#   '4.02',
#   '13.9',
#   '9.51',
#   '3.47',
#   1,
#   'C18H29NO2',
#   '291.44',
#   3,
#   2,
#   21,
#   'BASE',
#   '0.84'],
#  ['2',
#   'CHEMBL345524',
#   '6.21',
#   '6.22',
#   None,
#   '5.89',
#   '7',
#   4,
#   'C30H26F6N4O2',
#   '588.55',
#   6,
#   1,
#   42,
#   'NEUTRAL',
#   '0.19'],
#  ['0',
#   'CHEMBL1291',
#   '0.05',
#   '2.28',
#   '13.91',
#   '9.58',
#   '2.27',
#   1,
#   'C17H27NO4',
#   '309.41',
#   5,
#   2,
#   22,
#   'BASE',
#   '0.6'],
#  ['2',
#   'CHEMBL1292',
#   '5.8',
#   '7.46',
#   None,
#   '9.16',
#   '7.49',
#   3,
#   'C27H22Cl2N4',
#   '473.41',
#   4,
#   1,
#   33,
#   'BASE',
#   '0.27'],
#  ['2',
#   'CHEMBL1293',
#   '14.76',
#   '14.76',
#   None,
#   None,
#   '12.61',
#   0,
#   'C40H56',
#   '536.89',
#   0,
#   0,
#   40,
#   None,
#   '0.24'],
#  ['1',
#   'CHEMBL1294',
#   '0.98',
#   '2.82',
#   '12.8',
#   '9.28',
#   '3.17',
#   2,
#   'C20H24N2O2',
#   '324.42',
#   4,
#   1,
#   24,
#   'BASE',
#   '0.88'],
#  ['0',
#   'CHEMBL1295',
#   '6.49',
#   '6.57',
#   None,
#   '6.74',
#   '6.64',
#   3,
#   'C19H17Cl3N2S',
#   '411.79',
#   3,
#   0,
#   25,
#   'NEUTRAL',
#   '0.41'],
#  ['1',
#   'CHEMBL1296',
#   '-2.36',
#   '0.23',
#   '2.57',
#   '8.02',
#   '-0.65',
#   2,
#   'C18H23N9O4S3',
#   '525.64',
#   13,
#   3,
#   34,
#   'ACID',
#   '0.26'],
#  ['2',
#   'CHEMBL154111',
#   '-0.48',
#   '2.75',
#   '2.94',
#   None,
#   '2.31',
#   2,
#   'C14H10O5',
#   '258.23',
#   4,
#   2,
#   19,
#   'ACID',
#   '0.65'],
#  ['0',
#   'CHEMBL1297',
#   '0.63',
#   '3.72',
#   '4.2',
#   None,
#   '3.67',
#   2,
#   'C15H14O3',
#   '242.27',
#   2,
#   1,
#   18,
#   'ACID',
#   '0.89'],
#  ['2',
#   'CHEMBL345714',
#   '-4.14',
#   '-1',
#   '2.8',
#   None,
#   '-0.28',
#   1,
#   'C6H6N2O3',
#   '154.12',
#   3,
#   1,
#   11,
#   'ACID',
#   '0.45'],
#  ['0',
#   'CHEMBL157101',
#   '3.93',
#   '4.04',
#   None,
#   '6.88',
#   '4.21',
#   3,
#   'C26H28Cl2N4O4',
#   '531.44',
#   7,
#   0,
#   36,
#   'NEUTRAL',
#   '0.46'],
#  ['1',
#   'CHEMBL170',
#   '0.98',
#   '2.82',
#   '12.8',
#   '9.28',
#   '3.17',
#   2,
#   'C20H24N2O2',
#   '324.42',
#   4,
#   1,
#   24,
#   'BASE',
#   '0.88'],
#  ['2',
#   'CHEMBL346235',
#   '1.15',
#   '3.22',
#   None,
#   '9.49',
#   '3.08',
#   2,
#   'C15H25Cl2N3OS',
#   '366.36',
#   5,
#   0,
#   20,
#   'BASE',
#   '0.78'],
#  ['2',
#   'CHEMBL1301',
#   '-1.76',
#   '1.3',
#   '8.2',
#   '12.77',
#   '2.13',
#   2,
#   'C16H16N4O',
#   '280.33',
#   3,
#   5,
#   21,
#   'BASE',
#   '0.33'],
#  ['1',
#   'CHEMBL1303',
#   '3',
#   '4.36',
#   '10.49',
#   '8.83',
#   '4.27',
#   2,
#   'C19H25NOS',
#   '315.48',
#   3,
#   1,
#   22,
#   'BASE',
#   '0.86'],
#  ['2',
#   'CHEMBL349803',
#   '-0.63',
#   '2.3',
#   '10.22',
#   '4.34',
#   '2.42',
#   2,
#   'C17H18N2O5S',
#   '362.41',
#   5,
#   2,
#   25,
#   'NEUTRAL',
#   '0.85'],
#  ['2',
#   'CHEMBL1305',
#   '1.62',
#   '3.58',
#   None,
#   '10.29',
#   '2.69',
#   2,
#   'C17H19N3',
#   '265.36',
#   3,
#   1,
#   20,
#   'BASE',
#   '0.9'],
#  ['0',
#   'CHEMBL1306',
#   '3.57',
#   '4.19',
#   None,
#   '8.33',
#   '4.46',
#   3,
#   'C26H31Cl2N5O3',
#   '532.47',
#   8,
#   0,
#   36,
#   'NEUTRAL',
#   '0.42'],
#  ...]

# %%
# Add the data into the DB
c.executemany('INSERT INTO molecule VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)', mol_data)
conn.commit()

# %%
# Clean the indication data so entries can have multiple indications, and reshape for insertion into DB
ind_data = list()
for e in approved_mols:
    if e['indication_class'] is None:
        continue
    for i in e['indication_class'].replace(',', ';').split(';'):
            ind_data.append([e['molecule_chembl_id'], i])

# %%
c.executemany('INSERT INTO indication VALUES (?, ?)', ind_data)
conn.commit()

# %%
conn.close()
